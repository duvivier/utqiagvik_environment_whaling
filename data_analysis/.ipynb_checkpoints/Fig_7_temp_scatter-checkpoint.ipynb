# %% [markdown]
# # Utqiagvik **T2m vs. other variables** Analysis
# - Bowhead whale hunting relationships between annual mean temperature and other environmental variables
# - Notebook by Alice DuVivier (NCAR)
# - January 2026

# %%
import xarray as xr
import pandas as pd
import numpy as np
from glob import glob
import pop_tools
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import cartopy
import cartopy.crs as ccrs
import cmocean
import geopandas as gpd
from metpy.calc import wind_speed
from metpy.calc import wind_direction

# %% [markdown]
# ## Load Temperature Data

# %% [markdown]
# ### Load Barrow Observatory Data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/NOAA_GML_BRW_MET/'

# %%
# years from 1974-2024
years_obs = np.arange(1974,2025,1)
nyrs = len(years_obs)
print(nyrs)
# Out:
# 51

# %%
# preallocate some arrays
avg_array = np.zeros([nyrs])

# loop through each year to get the data and calculate annual average
for index, yy in enumerate(years_obs):
    file_in = 'brw_met_'+str(yy)+'.csv'
    #print(file_in)
    # load data with pandas
    df = pd.read_csv(dir_in+file_in)
    # read just the temperature values
    temp1 = df['T2m']
    # replace missing values (-999.9) with NaN
    temp2 = temp1.where(temp1> -999.9)
    # calculate annual mean and put this into an array
    avg_array[index] = temp2.mean()

# convert the numpy arrays to xarrays for easier plotting
data_obs = xr.DataArray(avg_array,dims=('years'))
data_obs['years'] = years_obs

# %%
# calculate an average temperature for 2000-2020
data_obs_sub = data_obs.where(data_obs.years >= 2000,drop=True)
data_obs_sub = data_obs_sub.where(data_obs_sub.years <= 2020, drop=True)
temp_avg_2000_2020 = data_obs_sub.mean()
temp_std_2000_2020 = data_obs_sub.std()
print(temp_avg_2000_2020)
print(temp_std_2000_2020)

# calculate an average temperature for 2014-2024
data_obs_sub = data_obs.where(data_obs.years >= 2014,drop=True)
temp_avg_2014_2024 = data_obs_sub.mean()
temp_std_2014_2024 = data_obs_sub.std()
print(temp_avg_2014_2024)
print(temp_std_2014_2024)
# Out:
# <xarray.DataArray ()> Size: 8B
# array(-10.09988811)
# <xarray.DataArray ()> Size: 8B
# array(1.2872061)
# <xarray.DataArray ()> Size: 8B
# array(-9.71130651)
# <xarray.DataArray ()> Size: 8B
# array(1.55803959)

# %% [markdown]
# ### Load CESM1-LE data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm1-le_utqiagvik/'
file_in = 'Utqiagvik_CESM1-LE_1920-2100_daily-TREFHT.nc'

ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates
# Out:
# (66065,)

# %%
temp_cesm1le = ds.TREFHT

# %% [markdown]
# ### Load CESM2-LE data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm2-le_utqiagvik/'
file_in = 'Utqiagvik_CESM2-LE_1920-2100_daily-TREFHT.nc'

ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates
# Out:
# (66065,)

# %%
temp_cesm2le = ds.TREFHT

# %% [markdown]
# ### Load CESM2-CMIP5 data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm2-cmip5_utqiagvik/'
file_in = 'Utqiagvik_CESM2-CMIP5_1920-2100_daily-TREFHT.nc'

ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates
# Out:
# (66065,)

# %%
temp_cesm2cmip5 = ds.TREFHT

# %% [markdown]
# ### Load MESACLIP data
# - Two future scenarios so must load all data separately

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/'

# %%
# historical data
file_in = 'Utqiagvik_MESACLIP_HIST_monthly-TREFHT.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# create full range of dates at daily frequency
dates = pd.date_range(start='1/1/1920', end='12/31/2005', freq='M')
# check that the # times matches above
#print(dates.shape)

# assign the time coordinate
ds['time'] = dates

# keep this data
temp_mesaclip_hist_pt = ds.data_pt
temp_mesaclip_hist_small_box = ds.data_small_box
temp_mesaclip_hist = ds.data_big_box

# %%
# rcp6.0 data
file_in = 'Utqiagvik_MESACLIP_RCP6.0_monthly-TREFHT.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# create full range of dates at daily frequency
dates = pd.date_range(start='1/1/2006', end='12/31/2104', freq='M')
# check that the # times matches above
#print(dates.shape)

# assign the time coordinate
ds['time'] = dates

# clip to end at in Dec. 2100
ds = ds.where(ds.time.dt.year <= 2100, drop=True)

# keep this data
temp_mesaclip_rcp60_pt = ds.data_pt
temp_mesaclip_rcp60_small_box = ds.data_small_box
temp_mesaclip_rcp60 = ds.data_big_box

# %%
# rcp8.5 data
file_in = 'Utqiagvik_MESACLIP_RCP8.5_monthly-TREFHT.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# create full range of dates at daily frequency
dates = pd.date_range(start='1/1/2006', end='12/31/2100', freq='M')
# check that the # times matches above
#print(dates.shape)

# assign the time coordinate
ds['time'] = dates

# keep this data
temp_mesaclip_rcp85_pt = ds.data_pt
temp_mesaclip_rcp85_small_box = ds.data_small_box
temp_mesaclip_rcp85 = ds.data_big_box

# %% [markdown]
# ### Get the different numbers of ensembles
# - Will need this later

# %%
# total ensemble members - will need this later
nens_cesm1le = len(temp_cesm1le.member_id)
print(nens_cesm1le)
nens_cesm2le = len(temp_cesm2le.member_id)
print(nens_cesm2le)
nens_cesm2cmip5 = len(temp_cesm2cmip5.member_id)
print(nens_cesm2cmip5)
nens_mesaclip_hist = len(temp_mesaclip_hist.member_id)
print(nens_mesaclip_hist)
nens_mesaclip_rcp60 = len(temp_mesaclip_rcp60.member_id)
print(nens_mesaclip_rcp60)
nens_mesaclip_rcp85 = len(temp_mesaclip_rcp85.member_id)
print(nens_mesaclip_rcp85)
# Out:
# 35
# 50
# 15
# 10
# 10
# 7

# %% [markdown]
# ## Load SIT Data

# %% [markdown]
# ### Load CESM1-LE data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm1-le_utqiagvik/'
file_in = 'Utqiagvik_CESM1-LE_1920-2100_daily-hi_d.nc'

ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates
# Out:
# (66065,)

# %%
sit_cesm1le = ds.hi_d

# %% [markdown]
# ### Load CESM2-LE data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm2-le_utqiagvik/'
file_in = 'Utqiagvik_CESM2-LE_1920-2100_daily-hi_d.nc'

ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates
# Out:
# (66065,)

# %%
sit_cesm2le = ds.hi_d

# %% [markdown]
# ### Load CESM2-CMIP5 data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm2-cmip5_utqiagvik/'
file_in = 'Utqiagvik_CESM2-CMIP5_1920-2100_daily-hi_d.nc'

ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates
# Out:
# (66065,)

# %%
sit_cesm2cmip5 = ds.hi_d

# %% [markdown]
# ### Load MESACLIP data
# - Two future scenarios so must load all data separately

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/'

# %%
# historical data
file_in = 'Utqiagvik_MESACLIP_HIST_daily-hi_d.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2005', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates

# keep this data
sit_mesaclip_hist_pt = ds.data_pt
sit_mesaclip_hist_small_box = ds.data_small_box
sit_mesaclip_hist = ds.data_big_box
# Out:
# (31390,)

# %%
# rcp6.0 data
file_in = 'Utqiagvik_MESACLIP_RCP6.0_daily-hi_d.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/2006', end='12/31/2104', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates

# clip to end at in Dec. 2100
ds = ds.where(ds.time.dt.year <= 2100, drop=True)

# keep this data
sit_mesaclip_rcp60_pt = ds.data_pt
sit_mesaclip_rcp60_small_box = ds.data_small_box
sit_mesaclip_rcp60 = ds.data_big_box
# Out:
# (36135,)

# %%
# rcp8.5 data
file_in = 'Utqiagvik_MESACLIP_RCP8.5_daily-hi_d.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/2006', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates

# keep this data
sit_mesaclip_rcp85_pt = ds.data_pt
sit_mesaclip_rcp85_small_box = ds.data_small_box
sit_mesaclip_rcp85 = ds.data_big_box
# Out:
# (34675,)

# %% [markdown]
# ## Load SIC Data

# %% [markdown]
# ### Load CESM1-LE data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm1-le_utqiagvik/'
file_in = 'Utqiagvik_CESM1-LE_1920-2100_daily-aice_d.nc'

ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates
# Out:
# (66065,)

# %%
sic_cesm1le = ds.aice_d

# %% [markdown]
# ### Load CESM2-LE data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm2-le_utqiagvik/'
file_in = 'Utqiagvik_CESM2-LE_1920-2100_daily-aice_d.nc'

ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates
# Out:
# (66065,)

# %%
sic_cesm2le = ds.aice_d * 100.0

# %% [markdown]
# ### Load CESM2-CMIP5 data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm2-cmip5_utqiagvik/'
file_in = 'Utqiagvik_CESM2-CMIP5_1920-2100_daily-aice_d.nc'

ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates
# Out:
# (66065,)

# %%
sic_cesm2cmip5 = ds.aice_d * 100.0

# %% [markdown]
# ### Load MESACLIP data
# - Two future scenarios so must load all data separately

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/'

# %%
# historical data
file_in = 'Utqiagvik_MESACLIP_HIST_daily-aice_d.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2005', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates

# keep this data
sic_mesaclip_hist_pt = ds.data_pt
sic_mesaclip_hist_small_box = ds.data_small_box
sic_mesaclip_hist = ds.data_big_box
# Out:
# (31390,)

# %%
# rcp6.0 data
file_in = 'Utqiagvik_MESACLIP_RCP6.0_daily-aice_d.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/2006', end='12/31/2104', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates

# clip to end at in Dec. 2100
ds = ds.where(ds.time.dt.year <= 2100, drop=True)

# keep this data
sic_mesaclip_rcp60_pt = ds.data_pt
sic_mesaclip_rcp60_small_box = ds.data_small_box
sic_mesaclip_rcp60 = ds.data_big_box
# Out:
# (36135,)

# %%
# rcp8.5 data
file_in = 'Utqiagvik_MESACLIP_RCP8.5_daily-aice_d.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/2006', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds['time'] = dates

# keep this data
sic_mesaclip_rcp85_pt = ds.data_pt
sic_mesaclip_rcp85_small_box = ds.data_small_box
sic_mesaclip_rcp85 = ds.data_big_box
# Out:
# (34675,)

# %% [markdown]
# ## Load Wind Data

# %% [markdown]
# ### Load CESM1-LE data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm1-le_utqiagvik/'
file_in1 = 'Utqiagvik_CESM1-LE_1920-2100_daily-UBOT.nc'
file_in2 = 'Utqiagvik_CESM1-LE_1920-2100_daily-VBOT.nc'

ds1 = xr.open_mfdataset(dir_in+file_in1, decode_times=False)
ds2 = xr.open_mfdataset(dir_in+file_in2, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)
ndates = len(dates)

# assign the time coordinate
ds1['time'] = dates
ds2['time'] = dates
# Out:
# (66065,)

# %%
# calculate wind speed
ws_temp = wind_speed(ds1.UBOT,ds2.VBOT)

# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens_cesm1le,ndates])
array[:,:] = ws_temp.values

# convert the numpy arrays to xarrays for easier plotting
ws_cesm1le = xr.DataArray(array,dims=('member_id','time'))
ws_cesm1le['member_id'] = ds1.member_id
ws_cesm1le['time'] = ds1.time

# %% [markdown]
# ### Load CESM2-LE data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm2-le_utqiagvik/'
file_in1 = 'Utqiagvik_CESM2-LE_1920-2100_daily-UBOT.nc'
file_in2 = 'Utqiagvik_CESM2-LE_1920-2100_daily-VBOT.nc'

ds1 = xr.open_mfdataset(dir_in+file_in1, decode_times=False)
ds2 = xr.open_mfdataset(dir_in+file_in2, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds1['time'] = dates
ds2['time'] = dates
# Out:
# (66065,)

# %%
# calculate wind speed
ws_temp = wind_speed(ds1.UBOT,ds2.VBOT)

# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens_cesm2le,ndates])
array[:,:] = ws_temp.values

# convert the numpy arrays to xarrays for easier plotting
ws_cesm2le = xr.DataArray(array,dims=('member_id','time'))
ws_cesm2le['member_id'] = ds1.member_id
ws_cesm2le['time'] = ds1.time

# %% [markdown]
# ### Load CESM2-CMIP5 data

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm2-cmip5_utqiagvik/'
file_in1 = 'Utqiagvik_CESM2-CMIP5_1920-2100_daily-UBOT.nc'
file_in2 = 'Utqiagvik_CESM2-CMIP5_1920-2100_daily-VBOT.nc'

ds1 = xr.open_mfdataset(dir_in+file_in1, decode_times=False)
ds2 = xr.open_mfdataset(dir_in+file_in2, decode_times=False)

# %%
# to make useable time coordinate, create arrays for yyyy-mm-dd (NO LEAP!)
# We know it's daily data for 19790101-20211231, not including leap days.

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
print(dates.shape)

# assign the time coordinate
ds1['time'] = dates
ds2['time'] = dates
# Out:
# (66065,)

# %%
# calculate wind speed
ws_temp = wind_speed(ds1.UBOT,ds2.VBOT)

# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens_cesm2cmip5,ndates])
array[:,:] = ws_temp.values

# convert the numpy arrays to xarrays for easier plotting
ws_cesm2cmip5 = xr.DataArray(array,dims=('member_id','time'))
ws_cesm2cmip5['member_id'] = ds1.member_id
ws_cesm2cmip5['time'] = ds1.time

# %% [markdown]
# ### Load MESACLIP data
# - Two future scenarios so must load all data separately

# %%
# directory path
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/'

# %%
# historical data
file_in1 = 'Utqiagvik_MESACLIP_HIST_daily-UBOT.nc'
ds1 = xr.open_mfdataset(dir_in+file_in1, decode_times=False)
file_in2 = 'Utqiagvik_MESACLIP_HIST_daily-VBOT.nc'
ds2 = xr.open_mfdataset(dir_in+file_in2, decode_times=False)

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/1920', end='12/31/2005', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
ndates = dates.shape
ndates = ndates[0]
print(ndates)

# get number of ensemble members for this data
nens = len(ds1.member_id)

# assign the time coordinate
ds1['time'] = dates
ds2['time'] = dates

### calculate wind speeds

# single pt
data1 = ds1.data_pt
data2 = ds2.data_pt
ws_temp = wind_speed(data1,data2)
# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens,ndates])
array[:,:] = ws_temp.values
# convert the numpy arrays to xarrays for easier plotting
ws_mesaclip_hist_pt = xr.DataArray(array,dims=('member_id','time'))
ws_mesaclip_hist_pt['member_id'] = ds1.member_id
ws_mesaclip_hist_pt['time'] = ds1.time

# small box
data1 = ds1.data_small_box.assign_attrs(units=ds1.data_pt.units, long_name=ds1.data_pt.long_name)
data2 = ds2.data_small_box.assign_attrs(units=ds2.data_pt.units, long_name=ds2.data_pt.long_name)
ws_temp = wind_speed(data1,data2)
# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens,ndates])
array[:,:] = ws_temp.values
# convert the numpy arrays to xarrays for easier plotting
ws_mesaclip_hist_small_box = xr.DataArray(array,dims=('member_id','time'))
ws_mesaclip_hist_small_box['member_id'] = ds1.member_id
ws_mesaclip_hist_small_box['time'] = ds1.time

# big box
data1 = ds1.data_big_box.assign_attrs(units=ds1.data_pt.units, long_name=ds1.data_pt.long_name)
data2 = ds2.data_big_box.assign_attrs(units=ds2.data_pt.units, long_name=ds2.data_pt.long_name)
ws_temp = wind_speed(data1,data2)
# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens,ndates])
array[:,:] = ws_temp.values
# convert the numpy arrays to xarrays for easier plotting
ws_mesaclip_hist = xr.DataArray(array,dims=('member_id','time'))
ws_mesaclip_hist['member_id'] = ds1.member_id
ws_mesaclip_hist['time'] = ds1.time
# Out:
# 31390

# %%
# rcp6.0 data
file_in1 = 'Utqiagvik_MESACLIP_RCP6.0_daily-UBOT.nc'
ds1 = xr.open_mfdataset(dir_in+file_in1, decode_times=False)
file_in2 = 'Utqiagvik_MESACLIP_RCP6.0_daily-VBOT.nc'
ds2 = xr.open_mfdataset(dir_in+file_in2, decode_times=False)

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/2006', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
ndates = dates.shape
ndates = ndates[0]
print(ndates)

# get number of ensemble members for this data
nens = len(ds1.member_id)

# assign the time coordinate
ds1['time'] = dates
ds2['time'] = dates

### calculate wind speeds

# single pt
data1 = ds1.data_pt
data2 = ds2.data_pt
ws_temp = wind_speed(data1,data2)
# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens,ndates])
array[:,:] = ws_temp.values
# convert the numpy arrays to xarrays for easier plotting
ws_mesaclip_rcp60_pt = xr.DataArray(array,dims=('member_id','time'))
ws_mesaclip_rcp60_pt['member_id'] = ds1.member_id
ws_mesaclip_rcp60_pt['time'] = ds1.time

# small box
data1 = ds1.data_small_box.assign_attrs(units=ds1.data_pt.units, long_name=ds1.data_pt.long_name)
data2 = ds2.data_small_box.assign_attrs(units=ds2.data_pt.units, long_name=ds2.data_pt.long_name)
ws_temp = wind_speed(data1,data2)
# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens,ndates])
array[:,:] = ws_temp.values
# convert the numpy arrays to xarrays for easier plotting
ws_mesaclip_rcp60_small_box = xr.DataArray(array,dims=('member_id','time'))
ws_mesaclip_rcp60_small_box['member_id'] = ds1.member_id
ws_mesaclip_rcp60_small_box['time'] = ds1.time

# big box
data1 = ds1.data_big_box.assign_attrs(units=ds1.data_pt.units, long_name=ds1.data_pt.long_name)
data2 = ds2.data_big_box.assign_attrs(units=ds2.data_pt.units, long_name=ds2.data_pt.long_name)
ws_temp = wind_speed(data1,data2)
# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens,ndates])
array[:,:] = ws_temp.values
# convert the numpy arrays to xarrays for easier plotting
ws_mesaclip_rcp60 = xr.DataArray(array,dims=('member_id','time'))
ws_mesaclip_rcp60['member_id'] = ds1.member_id
ws_mesaclip_rcp60['time'] = ds1.time
# Out:
# 34675

# %%
# rcp8.5 data
file_in1 = 'Utqiagvik_MESACLIP_RCP8.5_daily-UBOT.nc'
ds1 = xr.open_mfdataset(dir_in+file_in1, decode_times=False)
file_in2 = 'Utqiagvik_MESACLIP_RCP8.5_daily-VBOT.nc'
ds2 = xr.open_mfdataset(dir_in+file_in2, decode_times=False)

# create full range of dates at daily frequency
dr = pd.date_range(start='1/1/2006', end='12/31/2100', freq='D')
# remove leap days
dates = dr[(dr.day != 29) | (dr.month != 2)]
# check that the # times matches above
ndates = dates.shape
ndates = ndates[0]
print(ndates)

# get number of ensemble members for this data
nens = len(ds1.member_id)

# assign the time coordinate
ds1['time'] = dates
ds2['time'] = dates

### calculate wind speeds

# single pt
data1 = ds1.data_pt
data2 = ds2.data_pt
ws_temp = wind_speed(data1,data2)
# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens,ndates])
array[:,:] = ws_temp.values
# convert the numpy arrays to xarrays for easier plotting
ws_mesaclip_rcp85_pt = xr.DataArray(array,dims=('member_id','time'))
ws_mesaclip_rcp85_pt['member_id'] = ds1.member_id
ws_mesaclip_rcp85_pt['time'] = ds1.time

# small box
data1 = ds1.data_small_box.assign_attrs(units=ds1.data_pt.units, long_name=ds1.data_pt.long_name)
data2 = ds2.data_small_box.assign_attrs(units=ds2.data_pt.units, long_name=ds2.data_pt.long_name)
ws_temp = wind_speed(data1,data2)
# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens,ndates])
array[:,:] = ws_temp.values
# convert the numpy arrays to xarrays for easier plotting
ws_mesaclip_rcp85_small_box = xr.DataArray(array,dims=('member_id','time'))
ws_mesaclip_rcp85_small_box['member_id'] = ds1.member_id
ws_mesaclip_rcp85_small_box['time'] = ds1.time

# big box
data1 = ds1.data_big_box.assign_attrs(units=ds1.data_pt.units, long_name=ds1.data_pt.long_name)
data2 = ds2.data_big_box.assign_attrs(units=ds2.data_pt.units, long_name=ds2.data_pt.long_name)
ws_temp = wind_speed(data1,data2)
# put into an xarray more nicely because currently it causes issues with calculations
array = np.zeros([nens,ndates])
array[:,:] = ws_temp.values
# convert the numpy arrays to xarrays for easier plotting
ws_mesaclip_rcp85 = xr.DataArray(array,dims=('member_id','time'))
ws_mesaclip_rcp85['member_id'] = ds1.member_id
ws_mesaclip_rcp85['time'] = ds1.time
# Out:
# 34675

# %% [markdown]
# ## Process Annual Mean data
# - Timeseries: We need to first calculate the annual mean from daily data. Then from the annual mean temperatures for each ensemble member, we calculate mean and standard deviation. If we use daily data and average across everything then the variance is huge because of the annual cycle.

# %%
# years from 1920-2100
years_model = np.arange(1920,2101,1)
nyrs = len(years_model)
print(nyrs)
# Out:
# 181

# %%
# CESM1-LE
data_model = temp_cesm1le

# preallocate some arrays
avg_array = np.zeros([nyrs,nens_cesm1le])
std_array = np.zeros([nyrs,nens_cesm1le])

# convert to C from K
data_model = data_model - 273.15

### Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')

### Write variables
cesm1le_avg = model_ens_avg
cesm1le_std = model_ens_std

# %%
# CESM2-LE
data_model = temp_cesm2le

# preallocate some arrays
avg_array = np.zeros([nyrs,nens_cesm2le])
std_array = np.zeros([nyrs,nens_cesm2le])

# convert to C from K
data_model = data_model - 273.15

### Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')

### Write variables
cesm2le_avg = model_ens_avg
cesm2le_std = model_ens_std

# %%
# CESM2-CMIP5
data_model = temp_cesm2cmip5

# preallocate some arrays
avg_array = np.zeros([nyrs,nens_cesm2cmip5])
std_array = np.zeros([nyrs,nens_cesm2cmip5])

# convert to C from K
data_model = data_model - 273.15

### Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')

### Write variables
cesm2cmip5_avg = model_ens_avg
cesm2cmip5_std = model_ens_std

# %%
# MESACLIP - HIST
# 3 box size options!

### single pt
data_model = temp_mesaclip_hist_pt
# preallocate some arrays
avg_array = np.zeros([nyrs,nens_mesaclip_hist])
std_array = np.zeros([nyrs,nens_mesaclip_hist])
# convert to C from K
data_model = data_model - 273.15
# Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')
# Write variables
mesaclip_hist_pt_avg = model_ens_avg
mesaclip_hist_pt_std = model_ens_std

### small box
data_model = temp_mesaclip_hist_small_box
# preallocate some arrays
avg_array = np.zeros([nyrs,nens_mesaclip_hist])
std_array = np.zeros([nyrs,nens_mesaclip_hist])
# convert to C from K
data_model = data_model - 273.15
# Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')
# Write variables
mesaclip_hist_small_box_avg = model_ens_avg
mesaclip_hist_small_box_std = model_ens_std

### big box
data_model = temp_mesaclip_hist

# preallocate some arrays
avg_array = np.zeros([nyrs,nens_mesaclip_hist])
std_array = np.zeros([nyrs,nens_mesaclip_hist])

# convert to C from K
data_model = data_model - 273.15

### Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')

### Write variables
mesaclip_hist_avg = model_ens_avg
mesaclip_hist_std = model_ens_std

# %%
# MESACLIP - RCP6.0
# 3 box size options!

### single pt
data_model = temp_mesaclip_rcp60_pt
# preallocate some arrays
avg_array = np.zeros([nyrs,nens_mesaclip_rcp60])
std_array = np.zeros([nyrs,nens_mesaclip_rcp60])
# convert to C from K
data_model = data_model - 273.15
# Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')
# Write variables
mesaclip_rcp60_pt_avg = model_ens_avg
mesaclip_rcp60_pt_std = model_ens_std

### small box
data_model = temp_mesaclip_rcp60_small_box
# preallocate some arrays
avg_array = np.zeros([nyrs,nens_mesaclip_rcp60])
std_array = np.zeros([nyrs,nens_mesaclip_rcp60])
# convert to C from K
data_model = data_model - 273.15
# Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')
# Write variables
mesaclip_rcp60_small_box_avg = model_ens_avg
mesaclip_rcp60_small_box_std = model_ens_std

### big box
data_model = temp_mesaclip_rcp60

# preallocate some arrays
avg_array = np.zeros([nyrs,nens_mesaclip_rcp60])
std_array = np.zeros([nyrs,nens_mesaclip_rcp60])

# convert to C from K
data_model = data_model - 273.15

### Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')

### Write variables
mesaclip_rcp60_avg = model_ens_avg
mesaclip_rcp60_std = model_ens_std

# %%
# MESACLIP - RCP8.5
# 3 box size options!

### single pt
data_model = temp_mesaclip_rcp85_pt
# preallocate some arrays
avg_array = np.zeros([nyrs,nens_mesaclip_rcp85])
std_array = np.zeros([nyrs,nens_mesaclip_rcp85])
# convert to C from K
data_model = data_model - 273.15
# Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')
# Write variables
mesaclip_rcp85_pt_avg = model_ens_avg
mesaclip_rcp85_pt_std = model_ens_std

### small box
data_model = temp_mesaclip_rcp85_small_box
# preallocate some arrays
avg_array = np.zeros([nyrs,nens_mesaclip_rcp85])
std_array = np.zeros([nyrs,nens_mesaclip_rcp85])
# convert to C from K
data_model = data_model - 273.15
# Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')
# Write variables
mesaclip_rcp85_small_box_avg = model_ens_avg
mesaclip_rcp85_small_box_std = model_ens_std

### big box
data_model = temp_mesaclip_rcp85

# preallocate some arrays
avg_array = np.zeros([nyrs,nens_mesaclip_rcp85])
std_array = np.zeros([nyrs,nens_mesaclip_rcp85])

# convert to C from K
data_model = data_model - 273.15

### Get annual means from daily data
# loop through each year
for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get the data for this year
    temp = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # calculate annual mean
    avg_array[index,:] = temp.mean(dim='time')
# convert the numpy array to xarray
model_avg = xr.DataArray(avg_array,dims=('years','member_id'))
model_avg['years'] = years_model
# Now get the ensemble mean and variance
model_ens_avg = model_avg.mean(dim='member_id')
model_ens_std = model_avg.std(dim='member_id')

### Write variables
mesaclip_rcp85_avg = model_ens_avg
mesaclip_rcp85_std = model_ens_std

# %% [markdown]
# ## Process Spring SIC Frequency
# - Timeseries: We need to calculate the annual frequency of times below SIC thresholds for each ensemble member and each year. Thus, total number of points to plot will be nens*nyrs
#
# SIC thresholds
# - Covered:  SIC>=85%
# - MIZ:      15%<SIC<85%
# - Ice free: SIC<15%

# %%
# days are all days in April and May
ndays_spr = 30 + 31

# %%
# set thresholds
thresh1 = 85.0
thresh2 = 15.0

# %%
# subset to just this season
sic_cesm1le_seas = sic_cesm1le.isel(time=sic_cesm1le.time.dt.month.isin([3,4]))
sic_cesm2le_seas = sic_cesm2le.isel(time=sic_cesm2le.time.dt.month.isin([3,4]))
sic_cesm2cmip5_seas = sic_cesm2cmip5.isel(time=sic_cesm2cmip5.time.dt.month.isin([3,4]))
sic_mesaclip_hist_seas = sic_mesaclip_hist.isel(time=sic_mesaclip_hist.time.dt.month.isin([3,4]))
sic_mesaclip_rcp60_seas = sic_mesaclip_rcp60.isel(time=sic_mesaclip_rcp60.time.dt.month.isin([3,4]))
sic_mesaclip_rcp85_seas = sic_mesaclip_rcp85.isel(time=sic_mesaclip_rcp85.time.dt.month.isin([3,4]))

# single pt data
sic_mesaclip_hist_pt_seas = sic_mesaclip_hist_pt.isel(time=sic_mesaclip_hist_pt.time.dt.month.isin([3,4]))
sic_mesaclip_rcp60_pt_seas = sic_mesaclip_rcp60_pt.isel(time=sic_mesaclip_rcp60_pt.time.dt.month.isin([3,4]))
sic_mesaclip_rcp85_pt_seas = sic_mesaclip_rcp85_pt.isel(time=sic_mesaclip_rcp85_pt.time.dt.month.isin([3,4]))

# small box data
sic_mesaclip_hist_small_box_seas = sic_mesaclip_hist_small_box.isel(time=sic_mesaclip_hist_small_box.time.dt.month.isin([3,4]))
sic_mesaclip_rcp60_small_box_seas = sic_mesaclip_rcp60_small_box.isel(time=sic_mesaclip_rcp60_small_box.time.dt.month.isin([3,4]))
sic_mesaclip_rcp85_small_box_seas = sic_mesaclip_rcp85_small_box.isel(time=sic_mesaclip_rcp85_small_box.time.dt.month.isin([3,4]))

# %%
# CESM1-LE
times_tot = ndays_spr*nens_cesm1le
data_model = sic_cesm1le_seas

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_cesm1le = xr.DataArray(array_1,dims=('years'))
sic_thresh1_cesm1le['years'] = years_model
sic_thresh2_cesm1le = xr.DataArray(array_2,dims=('years'))
sic_thresh2_cesm1le['years'] = years_model

# %%
# CESM2-LE
times_tot = ndays_spr*nens_cesm2le
data_model = sic_cesm2le_seas

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_cesm2le = xr.DataArray(array_1,dims=('years'))
sic_thresh1_cesm2le['years'] = years_model
sic_thresh2_cesm2le = xr.DataArray(array_2,dims=('years'))
sic_thresh2_cesm2le['years'] = years_model

# %%
# CESM2-CMIP5
times_tot = ndays_spr*nens_cesm2cmip5
data_model = sic_cesm2cmip5_seas

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_cesm2cmip5 = xr.DataArray(array_1,dims=('years'))
sic_thresh1_cesm2cmip5['years'] = years_model
sic_thresh2_cesm2cmip5 = xr.DataArray(array_2,dims=('years'))
sic_thresh2_cesm2cmip5['years'] = years_model

# %%
# MESACLIP_hist
# 3 box sizes

data_model = sic_mesaclip_hist_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_mesaclip_hist = xr.DataArray(array_1,dims=('years'))
sic_thresh1_mesaclip_hist['years'] = years_model
sic_thresh2_mesaclip_hist = xr.DataArray(array_2,dims=('years'))
sic_thresh2_mesaclip_hist['years'] = years_model

### single pt
data_model = sic_mesaclip_hist_pt_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_mesaclip_hist_pt = xr.DataArray(array_1,dims=('years'))
sic_thresh1_mesaclip_hist_pt['years'] = years_model
sic_thresh2_mesaclip_hist_pt = xr.DataArray(array_2,dims=('years'))
sic_thresh2_mesaclip_hist_pt['years'] = years_model

### small box
data_model = sic_mesaclip_hist_small_box_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_mesaclip_hist_small_box = xr.DataArray(array_1,dims=('years'))
sic_thresh1_mesaclip_hist_small_box['years'] = years_model
sic_thresh2_mesaclip_hist_small_box = xr.DataArray(array_2,dims=('years'))
sic_thresh2_mesaclip_hist_small_box['years'] = years_model

# %%
# MESACLIP RCP6.0
# 3 box sizes

data_model = sic_mesaclip_rcp60_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_mesaclip_rcp60 = xr.DataArray(array_1,dims=('years'))
sic_thresh1_mesaclip_rcp60['years'] = years_model
sic_thresh2_mesaclip_rcp60 = xr.DataArray(array_2,dims=('years'))
sic_thresh2_mesaclip_rcp60['years'] = years_model

### single pt
data_model = sic_mesaclip_rcp60_pt_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_mesaclip_rcp60_pt = xr.DataArray(array_1,dims=('years'))
sic_thresh1_mesaclip_rcp60_pt['years'] = years_model
sic_thresh2_mesaclip_rcp60_pt = xr.DataArray(array_2,dims=('years'))
sic_thresh2_mesaclip_rcp60_pt['years'] = years_model

### small box
data_model = sic_mesaclip_rcp60_small_box_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_mesaclip_rcp60_small_box = xr.DataArray(array_1,dims=('years'))
sic_thresh1_mesaclip_rcp60_small_box['years'] = years_model
sic_thresh2_mesaclip_rcp60_small_box = xr.DataArray(array_2,dims=('years'))
sic_thresh2_mesaclip_rcp60_small_box['years'] = years_model

# %%
# MESACLIP RCP8.5
# 3 box sizes

data_model = sic_mesaclip_rcp85_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_mesaclip_rcp85 = xr.DataArray(array_1,dims=('years'))
sic_thresh1_mesaclip_rcp85['years'] = years_model
sic_thresh2_mesaclip_rcp85 = xr.DataArray(array_2,dims=('years'))
sic_thresh2_mesaclip_rcp85['years'] = years_model

### single pt
data_model = sic_mesaclip_rcp85_pt_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_mesaclip_rcp85_pt = xr.DataArray(array_1,dims=('years'))
sic_thresh1_mesaclip_rcp85_pt['years'] = years_model
sic_thresh2_mesaclip_rcp85_pt = xr.DataArray(array_2,dims=('years'))
sic_thresh2_mesaclip_rcp85_pt['years'] = years_model

### small box
data_model = sic_mesaclip_rcp85_small_box_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIC<85% conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIC<15% conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sic_thresh1_mesaclip_rcp85_small_box = xr.DataArray(array_1,dims=('years'))
sic_thresh1_mesaclip_rcp85_small_box['years'] = years_model
sic_thresh2_mesaclip_rcp85_small_box = xr.DataArray(array_2,dims=('years'))
sic_thresh2_mesaclip_rcp85_small_box['years'] = years_model

# %% [markdown]
# ## Process Spring SIT Frequency
# - Timeseries: We need to calculate the annual frequency of times below SIT thresholds for each ensemble member and each year. Thus, total number of points to plot will be nens*nyrs
#
# SIT thresholds
# - SIT<1m
# - SIT<2m
# - Curry and Lopez 2020 say that a minimum of 3-4ft (1m-1.2m) ice thickness is needed for a whale

# %%
# days are all days in April and May
ndays_spr = 30 + 31

# %%
# set thresholds
thresh1 = 2.0
thresh2 = 1.0

# %%
# subset to just this season
sit_cesm1le_seas = sit_cesm1le.isel(time=sit_cesm1le.time.dt.month.isin([3,4]))
sit_cesm2le_seas = sit_cesm2le.isel(time=sit_cesm2le.time.dt.month.isin([3,4]))
sit_cesm2cmip5_seas = sit_cesm2cmip5.isel(time=sit_cesm2cmip5.time.dt.month.isin([3,4]))
sit_mesaclip_hist_seas = sit_mesaclip_hist.isel(time=sit_mesaclip_hist.time.dt.month.isin([3,4]))
sit_mesaclip_rcp60_seas = sit_mesaclip_rcp60.isel(time=sit_mesaclip_rcp60.time.dt.month.isin([3,4]))
sit_mesaclip_rcp85_seas = sit_mesaclip_rcp85.isel(time=sit_mesaclip_rcp85.time.dt.month.isin([3,4]))

# single pt data
sit_mesaclip_hist_pt_seas = sit_mesaclip_hist_pt.isel(time=sit_mesaclip_hist_pt.time.dt.month.isin([3,4]))
sit_mesaclip_rcp60_pt_seas = sit_mesaclip_rcp60_pt.isel(time=sit_mesaclip_rcp60_pt.time.dt.month.isin([3,4]))
sit_mesaclip_rcp85_pt_seas = sit_mesaclip_rcp85_pt.isel(time=sit_mesaclip_rcp85_pt.time.dt.month.isin([3,4]))

# small box data
sit_mesaclip_hist_small_box_seas = sit_mesaclip_hist_small_box.isel(time=sit_mesaclip_hist_small_box.time.dt.month.isin([3,4]))
sit_mesaclip_rcp60_small_box_seas = sit_mesaclip_rcp60_small_box.isel(time=sit_mesaclip_rcp60_small_box.time.dt.month.isin([3,4]))
sit_mesaclip_rcp85_small_box_seas = sit_mesaclip_rcp85_small_box.isel(time=sit_mesaclip_rcp85_small_box.time.dt.month.isin([3,4]))

# %%
# CESM1-LE
times_tot = ndays_spr*nens_cesm1le
data_model = sit_cesm1le_seas

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_cesm1le = xr.DataArray(array_1,dims=('years'))
sit_thresh1_cesm1le['years'] = years_model
sit_thresh2_cesm1le = xr.DataArray(array_2,dims=('years'))
sit_thresh2_cesm1le['years'] = years_model

# %%
# CESM2-LE
times_tot = ndays_spr*nens_cesm2le
data_model = sit_cesm2le_seas

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    #count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_cesm2le = xr.DataArray(array_1,dims=('years'))
sit_thresh1_cesm2le['years'] = years_model
sit_thresh2_cesm2le = xr.DataArray(array_2,dims=('years'))
sit_thresh2_cesm2le['years'] = years_model

# %%
# CESM2-CMIP5
times_tot = ndays_spr*nens_cesm2cmip5
data_model = sit_cesm2cmip5_seas

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_cesm2cmip5 = xr.DataArray(array_1,dims=('years'))
sit_thresh1_cesm2cmip5['years'] = years_model
sit_thresh2_cesm2cmip5 = xr.DataArray(array_2,dims=('years'))
sit_thresh2_cesm2cmip5['years'] = years_model

# %%
# MESACLIP_hist
# 3 box sizes

data_model = sit_mesaclip_hist_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_mesaclip_hist = xr.DataArray(array_1,dims=('years'))
sit_thresh1_mesaclip_hist['years'] = years_model
sit_thresh2_mesaclip_hist = xr.DataArray(array_2,dims=('years'))
sit_thresh2_mesaclip_hist['years'] = years_model

### single pt
data_model = sit_mesaclip_hist_pt_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_mesaclip_hist_pt = xr.DataArray(array_1,dims=('years'))
sit_thresh1_mesaclip_hist_pt['years'] = years_model
sit_thresh2_mesaclip_hist_pt = xr.DataArray(array_2,dims=('years'))
sit_thresh2_mesaclip_hist_pt['years'] = years_model

### small box
data_model = sit_mesaclip_hist_small_box_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_mesaclip_hist_small_box = xr.DataArray(array_1,dims=('years'))
sit_thresh1_mesaclip_hist_small_box['years'] = years_model
sit_thresh2_mesaclip_hist_small_box = xr.DataArray(array_2,dims=('years'))
sit_thresh2_mesaclip_hist_small_box['years'] = years_model

# %%
# MESACLIP RCP6.0
# 3 box sizes

data_model = sit_mesaclip_rcp60_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_mesaclip_rcp60 = xr.DataArray(array_1,dims=('years'))
sit_thresh1_mesaclip_rcp60['years'] = years_model
sit_thresh2_mesaclip_rcp60 = xr.DataArray(array_2,dims=('years'))
sit_thresh2_mesaclip_rcp60['years'] = years_model

### single pt
data_model = sit_mesaclip_rcp60_pt_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_mesaclip_rcp60_pt = xr.DataArray(array_1,dims=('years'))
sit_thresh1_mesaclip_rcp60_pt['years'] = years_model
sit_thresh2_mesaclip_rcp60_pt = xr.DataArray(array_2,dims=('years'))
sit_thresh2_mesaclip_rcp60_pt['years'] = years_model

### small box
data_model = sit_mesaclip_rcp60_small_box_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_mesaclip_rcp60_small_box = xr.DataArray(array_1,dims=('years'))
sit_thresh1_mesaclip_rcp60_small_box['years'] = years_model
sit_thresh2_mesaclip_rcp60_small_box = xr.DataArray(array_2,dims=('years'))
sit_thresh2_mesaclip_rcp60_small_box['years'] = years_model

# %%
# MESACLIP RCP8.5
# 3 box sizes

data_model = sit_mesaclip_rcp85_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_mesaclip_rcp85 = xr.DataArray(array_1,dims=('years'))
sit_thresh1_mesaclip_rcp85['years'] = years_model
sit_thresh2_mesaclip_rcp85 = xr.DataArray(array_2,dims=('years'))
sit_thresh2_mesaclip_rcp85['years'] = years_model

### single pt
data_model = sit_mesaclip_rcp85_pt_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_mesaclip_rcp85_pt = xr.DataArray(array_1,dims=('years'))
sit_thresh1_mesaclip_rcp85_pt['years'] = years_model
sit_thresh2_mesaclip_rcp85_pt = xr.DataArray(array_2,dims=('years'))
sit_thresh2_mesaclip_rcp85_pt['years'] = years_model

### small box
data_model = sit_mesaclip_rcp85_small_box_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with SIT<2m conditions
    count = len(temp2.where((temp2 < thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with SIT<1m conditions
    count = len(temp2.where((temp2 < thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
sit_thresh1_mesaclip_rcp85_small_box = xr.DataArray(array_1,dims=('years'))
sit_thresh1_mesaclip_rcp85_small_box['years'] = years_model
sit_thresh2_mesaclip_rcp85_small_box = xr.DataArray(array_2,dims=('years'))
sit_thresh2_mesaclip_rcp85_small_box['years'] = years_model

# %% [markdown]
# ## Process Autumn WS Frequency
# - Timeseries: We need to calculate the annual frequency of times above WS thresholds for each ensemble member and each year. Thus, total number of points to plot will be nens*nyrs
#
# Some Thresholds
# - Small boat: WS>=6m/s
# - Big boat:   WS>=11m/s
#
# Beaufort Scale (https://windy.app/blog/wind-speed-beaufort-scale.html)
# - Strong Breeze: WS>=11m/s
# - Gale: WS>=17m/s

# %%
# days are all days in SON
ndays_fall = 30 + 31 + 30

# %%
# set thresholds
thresh1 = 11.0
thresh2 = 17.0

# %%
# subset to just this season
ws_cesm1le_seas = ws_cesm1le.isel(time=ws_cesm1le.time.dt.month.isin([9,10,11]))
ws_cesm2le_seas = ws_cesm2le.isel(time=ws_cesm2le.time.dt.month.isin([9,10,11]))
ws_cesm2cmip5_seas = ws_cesm2cmip5.isel(time=ws_cesm2cmip5.time.dt.month.isin([9,10,11]))
ws_mesaclip_hist_seas = ws_mesaclip_hist.isel(time=ws_mesaclip_hist.time.dt.month.isin([9,10,11]))
ws_mesaclip_rcp60_seas = ws_mesaclip_rcp60.isel(time=ws_mesaclip_rcp60.time.dt.month.isin([9,10,11]))
ws_mesaclip_rcp85_seas = ws_mesaclip_rcp85.isel(time=ws_mesaclip_rcp85.time.dt.month.isin([9,10,11]))

# single pt data
ws_mesaclip_hist_pt_seas = ws_mesaclip_hist_pt.isel(time=ws_mesaclip_hist_pt.time.dt.month.isin([9,10,11]))
ws_mesaclip_rcp60_pt_seas = ws_mesaclip_rcp60_pt.isel(time=ws_mesaclip_rcp60_pt.time.dt.month.isin([9,10,11]))
ws_mesaclip_rcp85_pt_seas = ws_mesaclip_rcp85_pt.isel(time=ws_mesaclip_rcp85_pt.time.dt.month.isin([9,10,11]))

# small box data
ws_mesaclip_hist_small_box_seas = ws_mesaclip_hist_small_box.isel(time=ws_mesaclip_hist_small_box.time.dt.month.isin([9,10,11]))
ws_mesaclip_rcp60_small_box_seas = ws_mesaclip_rcp60_small_box.isel(time=ws_mesaclip_rcp60_small_box.time.dt.month.isin([9,10,11]))
ws_mesaclip_rcp85_small_box_seas = ws_mesaclip_rcp85_small_box.isel(time=ws_mesaclip_rcp85_small_box.time.dt.month.isin([9,10,11]))

# %%
# CESM1-LE
times_tot = ndays_fall*nens_cesm1le
data_model = ws_cesm1le_seas

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_cesm1le = xr.DataArray(array_1,dims=('years'))
ws_thresh1_cesm1le['years'] = years_model
ws_thresh2_cesm1le = xr.DataArray(array_2,dims=('years'))
ws_thresh2_cesm1le['years'] = years_model

# %%
# CESM2-LE
times_tot = ndays_fall*nens_cesm2le
data_model = ws_cesm2le_seas

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_cesm2le = xr.DataArray(array_1,dims=('years'))
ws_thresh1_cesm2le['years'] = years_model
ws_thresh2_cesm2le = xr.DataArray(array_2,dims=('years'))
ws_thresh2_cesm2le['years'] = years_model

# %%
# CESM2-CMIP5
times_tot = ndays_fall*nens_cesm2cmip5
data_model = ws_cesm2cmip5_seas

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_cesm2cmip5 = xr.DataArray(array_1,dims=('years'))
ws_thresh1_cesm2cmip5['years'] = years_model
ws_thresh2_cesm2cmip5 = xr.DataArray(array_2,dims=('years'))
ws_thresh2_cesm2cmip5['years'] = years_model

# %%
# MESACLIP_hist
# 3 box sizes

data_model = ws_mesaclip_hist_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_mesaclip_hist = xr.DataArray(array_1,dims=('years'))
ws_thresh1_mesaclip_hist['years'] = years_model
ws_thresh2_mesaclip_hist = xr.DataArray(array_2,dims=('years'))
ws_thresh2_mesaclip_hist['years'] = years_model

### single pt
data_model = ws_mesaclip_hist_pt_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_mesaclip_hist_pt = xr.DataArray(array_1,dims=('years'))
ws_thresh1_mesaclip_hist_pt['years'] = years_model
ws_thresh2_mesaclip_hist_pt = xr.DataArray(array_2,dims=('years'))
ws_thresh2_mesaclip_hist_pt['years'] = years_model

### small box
data_model = ws_mesaclip_hist_small_box_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_mesaclip_hist_small_box = xr.DataArray(array_1,dims=('years'))
ws_thresh1_mesaclip_hist_small_box['years'] = years_model
ws_thresh2_mesaclip_hist_small_box = xr.DataArray(array_2,dims=('years'))
ws_thresh2_mesaclip_hist_small_box['years'] = years_model

# %%
# MESACLIP RCP6.0
# 3 box sizes

data_model = ws_mesaclip_rcp60_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_mesaclip_rcp60 = xr.DataArray(array_1,dims=('years'))
ws_thresh1_mesaclip_rcp60['years'] = years_model
ws_thresh2_mesaclip_rcp60 = xr.DataArray(array_2,dims=('years'))
ws_thresh2_mesaclip_rcp60['years'] = years_model

### single pt
data_model = ws_mesaclip_rcp60_pt_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_mesaclip_rcp60_pt = xr.DataArray(array_1,dims=('years'))
ws_thresh1_mesaclip_rcp60_pt['years'] = years_model
ws_thresh2_mesaclip_rcp60_pt = xr.DataArray(array_2,dims=('years'))
ws_thresh2_mesaclip_rcp60_pt['years'] = years_model

### small box
data_model = ws_mesaclip_rcp60_small_box_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_mesaclip_rcp60_small_box = xr.DataArray(array_1,dims=('years'))
ws_thresh1_mesaclip_rcp60_small_box['years'] = years_model
ws_thresh2_mesaclip_rcp60_small_box = xr.DataArray(array_2,dims=('years'))
ws_thresh2_mesaclip_rcp60_small_box['years'] = years_model

# %%
# MESACLIP RCP8.5
# 3 box sizes

data_model = ws_mesaclip_rcp85_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_mesaclip_rcp85 = xr.DataArray(array_1,dims=('years'))
ws_thresh1_mesaclip_rcp85['years'] = years_model
ws_thresh2_mesaclip_rcp85 = xr.DataArray(array_2,dims=('years'))
ws_thresh2_mesaclip_rcp85['years'] = years_model

### single pt
data_model = ws_mesaclip_rcp85_pt_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_mesaclip_rcp85_pt = xr.DataArray(array_1,dims=('years'))
ws_thresh1_mesaclip_rcp85_pt['years'] = years_model
ws_thresh2_mesaclip_rcp85_pt = xr.DataArray(array_2,dims=('years'))
ws_thresh2_mesaclip_rcp85_pt['years'] = years_model

### small box
data_model = ws_mesaclip_rcp85_small_box_seas
nens = len(data_model.member_id)
times_tot = ndays_spr*nens

# loop through each year to calculate fractions
array_1 = np.zeros([nyrs])
array_2 = np.zeros([nyrs])

for index, yy in enumerate(years_model):
    #print(f"Index {index}: {yy}")
    # get data for this year
    temp1 = data_model.isel(time=data_model.time.dt.year.isin([yy]))
    # make 1d and put into the new array
    temp2 = temp1.stack(all=("member_id","time"))
    temp2 = temp2.compute()
    # count days with WS>11m/s conditions
    count = len(temp2.where((temp2 > thresh1),drop=True))
    array_1[index] = 100.0*(count/times_tot)    
    # count days with WS>17m/s conditions
    count = len(temp2.where((temp2 > thresh2),drop=True))
    array_2[index] = 100.0*(count/times_tot)

# convert the numpy arrays to xarrays for easier plotting
ws_thresh1_mesaclip_rcp85_small_box = xr.DataArray(array_1,dims=('years'))
ws_thresh1_mesaclip_rcp85_small_box['years'] = years_model
ws_thresh2_mesaclip_rcp85_small_box = xr.DataArray(array_2,dims=('years'))
ws_thresh2_mesaclip_rcp85_small_box['years'] = years_model

# %% [markdown]
# ## Plot timeseries and scatter plots

# %%
# set an output directory for figures
dir_out = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/utqiagvik_analysis/version_5/'

# %%
# calculate an average temperature for 2000-2020
print(temp_avg_2000_2020)

# calculate an average temperature for 2014-2024
print(temp_avg_2014_2024)
# Out:
# <xarray.DataArray ()> Size: 8B
# array(-10.09988811)
# <xarray.DataArray ()> Size: 8B
# array(-9.71130651)

# %%
xticks = np.arange(-15,5,5)
xticks

yticks = np.arange(20,60,10)
yticks
# Out:
# array([20, 30, 40, 50])

# %% [markdown]
# ### All Models on one Plot

# %%
# create figure
fig = plt.figure(figsize=(20,15))
# now loop through months to create subpanels
fout = 'fig_7_utq_temperature_scatter'

# Make subplot - note it's nrow x ncol x index (starting upper left)
############
### First grouping of 3 - Different models/forcing but same resolution 
### Plot 1 - T2m vs. SIC ###
ax = fig.add_subplot(2,3,1)
# set data
ax.scatter(cesm2le_avg,sic_thresh1_cesm2le,color="royalblue",marker=".",label='CESM2-LE')
ax.scatter(cesm1le_avg,sic_thresh1_cesm1le,color="firebrick",marker=".",label='CESM1-LE')
ax.scatter(cesm2cmip5_avg,sic_thresh1_cesm2cmip5,color="gold",marker=".",label='CESM2-CMIP5')
ax.scatter(mesaclip_hist_avg,sic_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - HIST')
ax.scatter(mesaclip_rcp60_avg,sic_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - RCP6.0')
#ax.scatter(mesaclip_rcp85_avg,sic_thresh1_mesaclip_rcp85,color="plum",marker=".",label='MESACLIP - RCP8.5')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('a) ',loc='left',fontsize=15)
plt.xlabel('Annual Mean Temperature (C)',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-16,3])
ax.set_xticks(xticks)
plt.ylabel('Percent of Spring Days with SIC<85%',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([-1,100.0])
plt.grid()
#plt.legend(loc='upper left', fontsize=15, ncol=1);

### Plot 2 - T2m vs. SIT ###
ax = fig.add_subplot(2,3,2)
# set data
ax.scatter(cesm2le_avg,sit_thresh1_cesm2le,color="royalblue",marker=".",label='CESM2-LE')
ax.scatter(cesm1le_avg,sit_thresh1_cesm1le,color="firebrick",marker=".",label='CESM1-LE')
ax.scatter(cesm2cmip5_avg,sit_thresh1_cesm2cmip5,color="gold",marker=".",label='CESM2-CMIP5')
ax.scatter(mesaclip_hist_avg,sit_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - HIST')
ax.scatter(mesaclip_rcp60_avg,sit_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - RCP6.0')
#ax.scatter(mesaclip_rcp85_avg,sit_thresh1_mesaclip_rcp85,color="plum",marker=".",label='MESACLIP - RCP8.5')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('b) ',loc='left',fontsize=15)
plt.xlabel('Annual Mean Temperature (C)',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-16,3])
ax.set_xticks(xticks)
plt.ylabel('Percent of Spring Days with SIT<2m',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([-1,100.0])
plt.grid()
#plt.legend(loc='upper left', fontsize=15, ncol=1);

### Plot 3 - T2m vs. WS ###
ax = fig.add_subplot(2,3,3)
# set data
ax.scatter(cesm2le_avg,ws_thresh1_cesm2le,color="royalblue",marker=".",label='CESM2-LE')
ax.scatter(cesm1le_avg,ws_thresh1_cesm1le,color="firebrick",marker=".",label='CESM1-LE')
ax.scatter(cesm2cmip5_avg,ws_thresh1_cesm2cmip5,color="gold",marker=".",label='CESM2-CMIP5')
ax.scatter(mesaclip_hist_avg,ws_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - HIST')
ax.scatter(mesaclip_rcp60_avg,ws_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - RCP6.0')
#ax.scatter(mesaclip_rcp85_avg,ws_thresh1_mesaclip_rcp85,color="plum",marker=".",label='MESACLIP - RCP8.5')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('c) ',loc='left',fontsize=15)
plt.xlabel('Annual Mean Temperature (C)',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-16,3])
ax.set_xticks(xticks)
plt.ylabel('Percent of Autumn Days with WS>11ms',fontsize=15)
plt.yticks(fontsize=15)
#plt.ylim([-1,100.0])
plt.ylim([15.0,45.0])
ax.set_yticks(yticks)
plt.grid()
#plt.legend(loc='upper left', fontsize=15, ncol=1);
############

############
### Second grouping of 3 - Impact of resolution
### Plot 4 - T2m vs. SIC ###
ax = fig.add_subplot(2,3,4)
# set data
ax.scatter(mesaclip_hist_avg,sic_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_rcp60_avg,sic_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_hist_small_box_avg,sic_thresh1_mesaclip_hist_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_rcp60_small_box_avg,sic_thresh1_mesaclip_rcp60_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_hist_pt_avg,sic_thresh1_mesaclip_hist_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
ax.scatter(mesaclip_rcp60_pt_avg,sic_thresh1_mesaclip_rcp60_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('d) ',loc='left',fontsize=15)
plt.xlabel('Annual Mean Temperature (C)',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-16,3])
ax.set_xticks(xticks)
plt.ylabel('Percent of Spring Days with SIC<85%',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([-1,100.0])
plt.grid()
#plt.legend(loc='upper left', fontsize=15, ncol=1);

### Plot 5 - T2m vs. SIT ###
ax = fig.add_subplot(2,3,5)
# set data
ax.scatter(mesaclip_hist_avg,sit_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_rcp60_avg,sit_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_hist_small_box_avg,sit_thresh1_mesaclip_hist_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_rcp60_small_box_avg,sit_thresh1_mesaclip_rcp60_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_hist_pt_avg,sit_thresh1_mesaclip_hist_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
ax.scatter(mesaclip_rcp60_pt_avg,sit_thresh1_mesaclip_rcp60_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('e) ',loc='left',fontsize=15)
plt.xlabel('Annual Mean Temperature (C)',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-16,3])
ax.set_xticks(xticks)
plt.ylabel('Percent of Spring Days with SIT<2m',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([-1,100.0])
plt.grid()
#plt.legend(loc='upper left', fontsize=15, ncol=1);

### Plot 6 - T2m vs. WS ###
ax = fig.add_subplot(2,3,6)
# set data
ax.scatter(mesaclip_hist_avg,ws_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_rcp60_avg,ws_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_hist_small_box_avg,ws_thresh1_mesaclip_hist_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_rcp60_small_box_avg,ws_thresh1_mesaclip_rcp60_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_hist_pt_avg,ws_thresh1_mesaclip_hist_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
ax.scatter(mesaclip_rcp60_pt_avg,ws_thresh1_mesaclip_rcp60_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('f) ',loc='left',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-16,3])
ax.set_xticks(xticks)
plt.ylabel('Percent of Autumn Days with WS>11ms',fontsize=15)
plt.yticks(fontsize=15)
#plt.ylim([-1,100.0])
plt.ylim([15.0,45.0])
ax.set_yticks(yticks)
plt.grid()
#plt.legend(loc='upper left', fontsize=15, ncol=1);
############

# Finalize figure and save
fig = plt.savefig(fout+'.png', bbox_inches='tight', dpi=200)
fig = plt.savefig(dir_out+fout+'.png', bbox_inches='tight', dpi=200)

# %%
# create figure
fig = plt.figure(figsize=(20,15))
# now loop through months to create subpanels
fout = 'fig_7_legend'

# Make subplot - note it's nrow x ncol x index (starting upper left)
############
### First grouping of 3 - Different models/forcing but same resolution 
### Plot 1 - T2m vs. SIC ###
ax = fig.add_subplot(2,3,1)
# set data
ax.scatter(cesm2le_avg,sic_thresh1_cesm2le,color="royalblue",marker=".",label='CESM2-LE')
ax.scatter(cesm1le_avg,sic_thresh1_cesm1le,color="firebrick",marker=".",label='CESM1-LE')
ax.scatter(cesm2cmip5_avg,sic_thresh1_cesm2cmip5,color="gold",marker=".",label='CESM2-CMIP5')
ax.scatter(mesaclip_hist_avg,sic_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP')
#ax.scatter(mesaclip_rcp85_avg,sic_thresh1_mesaclip_rcp85,color="plum",marker=".",label='MESACLIP - RCP8.5')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
#plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('a) ',loc='left',fontsize=15)
plt.xlabel('Annual Mean Temperature (C)',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-70,6])
ax.set_xticks(xticks)
plt.ylabel('Percent of Spring Days with SIC<85%',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([-1,100.0])
#plt.grid()
plt.legend(loc='upper left', fontsize=15, ncol=1);

### Plot 2 - T2m vs. SIT ###
ax = fig.add_subplot(2,3,2)
# set data
ax.scatter(cesm2le_avg,sit_thresh1_cesm2le,color="royalblue",marker=".",label='CESM2-LE')
ax.scatter(cesm1le_avg,sit_thresh1_cesm1le,color="firebrick",marker=".",label='CESM1-LE')
ax.scatter(cesm2cmip5_avg,sit_thresh1_cesm2cmip5,color="gold",marker=".",label='CESM2-CMIP5')
ax.scatter(mesaclip_hist_avg,sit_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - HIST')
ax.scatter(mesaclip_rcp60_avg,sit_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - RCP6.0')
ax.scatter(mesaclip_rcp85_avg,sit_thresh1_mesaclip_rcp85,color="plum",marker=".",label='MESACLIP - RCP8.5')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('b) ',loc='left',fontsize=15)
plt.xlabel('Annual Mean Temperature (C)',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-16,6])
ax.set_xticks(xticks)
plt.ylabel('Percent of Spring Days with SIT<2m',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([-1,100.0])
plt.grid()
#plt.legend(loc='upper left', fontsize=15, ncol=1);

### Plot 3 - T2m vs. WS ###
ax = fig.add_subplot(2,3,3)
# set data
ax.scatter(cesm2le_avg,ws_thresh1_cesm2le,color="royalblue",marker=".",label='CESM2-LE')
ax.scatter(cesm1le_avg,ws_thresh1_cesm1le,color="firebrick",marker=".",label='CESM1-LE')
ax.scatter(cesm2cmip5_avg,ws_thresh1_cesm2cmip5,color="gold",marker=".",label='CESM2-CMIP5')
ax.scatter(mesaclip_hist_avg,ws_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - HIST')
ax.scatter(mesaclip_rcp60_avg,ws_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - RCP6.0')
ax.scatter(mesaclip_rcp85_avg,ws_thresh1_mesaclip_rcp85,color="plum",marker=".",label='MESACLIP - RCP8.5')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('c) ',loc='left',fontsize=15)
plt.xlabel('Annual Mean Temperature (C)',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-16,6])
ax.set_xticks(xticks)
plt.ylabel('Percent of Autumn Days with WS>11ms',fontsize=15)
plt.yticks(fontsize=15)
#plt.ylim([-1,100.0])
plt.ylim([15.0,45.0])
ax.set_yticks(yticks)
plt.grid()
#plt.legend(loc='upper left', fontsize=15, ncol=1);
############

############
### Second grouping of 3 - Impact of resolution
### Plot 4 - T2m vs. SIC ###
ax = fig.add_subplot(2,3,4)
# set data
ax.scatter(mesaclip_hist_avg,sic_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - Big Box Avg.')
#ax.scatter(mesaclip_rcp60_avg,sic_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_hist_small_box_avg,sic_thresh1_mesaclip_hist_small_box,color="cyan",marker=".",label='MESACLIP - Small Box Avg.')
#ax.scatter(mesaclip_rcp60_small_box_avg,sic_thresh1_mesaclip_rcp60_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_hist_pt_avg,sic_thresh1_mesaclip_hist_pt,color="limegreen",marker=".",label='MESACLIP - Single Point')
#ax.scatter(mesaclip_rcp60_pt_avg,sic_thresh1_mesaclip_rcp60_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
#plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('d) ',loc='left',fontsize=15)
plt.xlabel('Annual Mean Temperature (C)',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-80,6])
ax.set_xticks(xticks)
plt.ylabel('Percent of Spring Days with SIC<85%',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([-1,100.0])
#plt.grid()
plt.legend(loc='upper left', fontsize=15, ncol=1);

### Plot 5 - T2m vs. SIT ###
ax = fig.add_subplot(2,3,5)
# set data
ax.scatter(mesaclip_hist_avg,sit_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_rcp60_avg,sit_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_hist_small_box_avg,sit_thresh1_mesaclip_hist_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_rcp60_small_box_avg,sit_thresh1_mesaclip_rcp60_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_hist_pt_avg,sit_thresh1_mesaclip_hist_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
ax.scatter(mesaclip_rcp60_pt_avg,sit_thresh1_mesaclip_rcp60_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('e) ',loc='left',fontsize=15)
plt.xlabel('Annual Mean Temperature (C)',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-16,6])
ax.set_xticks(xticks)
plt.ylabel('Percent of Spring Days with SIT<2m',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([-1,100.0])
plt.grid()
#plt.legend(loc='upper left', fontsize=15, ncol=1);

### Plot 6 - T2m vs. WS ###
ax = fig.add_subplot(2,3,6)
# set data
ax.scatter(mesaclip_hist_avg,ws_thresh1_mesaclip_hist,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_rcp60_avg,ws_thresh1_mesaclip_rcp60,color="blueviolet",marker=".",label='MESACLIP - Big Box')
ax.scatter(mesaclip_hist_small_box_avg,ws_thresh1_mesaclip_hist_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_rcp60_small_box_avg,ws_thresh1_mesaclip_rcp60_small_box,color="cyan",marker=".",label='MESACLIP - Small Box')
ax.scatter(mesaclip_hist_pt_avg,ws_thresh1_mesaclip_hist_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
ax.scatter(mesaclip_rcp60_pt_avg,ws_thresh1_mesaclip_rcp60_pt,color="limegreen",marker=".",label='MESACLIP - Pt')
# add line for average of Barrow Observatory for 2014-2024
plt.axvline(x=temp_avg_2014_2024, color='black', linestyle='-',label='Obs: 2014-2024 avg')
plt.axvline(x=temp_avg_2014_2024+temp_std_2014_2024, color='black', linestyle='--',label='Obs: 2014-2024 std')
plt.axvline(x=temp_avg_2014_2024-temp_std_2014_2024, color='black', linestyle='--')
# modify labels and legend
plt.title('f) ',loc='left',fontsize=15)
plt.xticks(fontsize=15,rotation=45)
plt.xlim([-16,6])
ax.set_xticks(xticks)
plt.ylabel('Percent of Autumn Days with WS>11ms',fontsize=15)
plt.yticks(fontsize=15)
#plt.ylim([-1,100.0])
plt.ylim([15.0,45.0])
ax.set_yticks(yticks)
plt.grid()
#plt.legend(loc='upper left', fontsize=15, ncol=1);
############

# Finalize figure and save
fig = plt.savefig(fout+'.png', bbox_inches='tight', dpi=200)
fig = plt.savefig(dir_out+fout+'.png', bbox_inches='tight', dpi=200)
