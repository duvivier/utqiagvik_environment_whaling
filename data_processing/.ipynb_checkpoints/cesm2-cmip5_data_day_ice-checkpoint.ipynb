# %% [markdown]
# # Arctic Sea ice files
#
# * **Description**: Creates file of Utqiagvik data from CESM2-CMIP5
# * **Input data**: CESM2-CMIP5 daily timeseries data
# * **Output data**: Netcdf with data
# * **Creator**: Alice DuVivier
# * **Date**: September 2024

# %% [markdown]
# ### Import Packages

# %%
#import utils
import xarray as xr
import numpy as np
from glob import glob
import importlib
from datetime import datetime
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
import cmocean

# %% [markdown]
# ## Find point nearest Utqiagvik

# %%
# set latitude and longitude of Village (longitudes must be in 0-360)
name_village = 'Utqiagvik'
lat_village = 71.29
lon_village = 203.21
#longitue = -156.79

# %%
# set a dataset to read in to get grid information
dir_in = '/glade/u/home/duvivier/masks/'
file_in = 'ocn_grid_gx1v7.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# grab lat and lon data
lat2d = ds.TLAT
lon2d = ds.TLONG
land = ds.KMT

# %%
# First, find the index of the grid point nearest a specific lat/lon.   
abslat = np.abs(lat2d - lat_village)
abslon = np.abs(lon2d - lon_village)
c = np.maximum(abslon, abslat)

# find the smallest values
([xloc], [yloc]) = np.where(c == np.min(c))

# print index values
print(xloc,yloc)
# Out:
# 343 205

# %%
# Check how close these are to the latitude and longitude of the village
print(name_village+': '+str(lat_village)+','+str(lon_village))

lat_grid = lat2d.isel(nlat=xloc,nlon=yloc).values
lon_grid = lon2d.isel(nlat=xloc,nlon=yloc).values
print('grid point: '+str(lat_grid)+','+str(lon_grid))
# Out:
# Utqiagvik: 71.29,203.21
# grid point: 71.55580708124228,203.34041769239948

# %%
# Plot the Grid points to ensure we have the closest point for plots
fig = plt.figure(figsize=(20,20))

# make plot
ax = plt.subplot(1,1,1)
ax = plt.subplot(1,1,1,projection = ccrs.NorthPolarStereo(central_longitude=180.0) )
ax.set_extent([-140, -179, 72, 69], crs=ccrs.PlateCarree())

# do a pcolormesh plot of input
cs0 = ax.pcolormesh(lon2d, lat2d,
                    land,
                    cmap = cmocean.cm.thermal, vmin = 0, vmax = 50,
                    transform=ccrs.PlateCarree())

# do scatter plot of all grid values
cs1 = ax.plot(lon2d, lat2d,
                 land,
                 c='white',marker='.', linestyle='none',
                 transform=ccrs.PlateCarree())

# Plot requested lat/lon point
cs2 = ax.scatter(lon_village, lat_village, marker='.',c='red', transform=ccrs.PlateCarree())
tx1 = ax.text(lon_village, lat_village, 'requested', c='red', transform=ccrs.PlateCarree())

# Plot nearest point in the array red
cs4 = plt.scatter(lon2d.isel(nlat=xloc,nlon=yloc), lat2d.isel(nlat=xloc,nlon=yloc), marker='x', color='orange', transform=ccrs.PlateCarree())
tx2 = plt.text(lon2d.isel(nlat=xloc,nlon=yloc), lat2d.isel(nlat=xloc,nlon=yloc), 'selected', c='orange', transform=ccrs.PlateCarree())

# %% [markdown]
# - This point is an ocean point and is closest to the Utqiagvik village. Proceed!

# %%
# print original index values
print(xloc,yloc)
# Out:
# 343 205

# %% [markdown]
# ## Read in 15 cesm2-cmip5 ensemble members

# %%
# Select variable of interest and locate the files
# varname options = 'aice_d','hi_d'

varname = 'hi_d'
path = '/glade/campaign/cesm/development/cross-wg/CESM2_CMIP5/'

# %%
# list all 15 ensemble numbers
ens_mems = ['001', '002', '003', '004', '005',
            '006', '007', '008', '009', '010',
            '011', '012', '013', '014', '015']

# %% [markdown]
# ### Load historical data

# %%
# %%time

print('loading historical data')
ds_hist = xr.Dataset()

for m in ens_mems:
    print(m)

    case = 'b.e21.BHIST.f09_g17.cesm2-cmip5.' + m
    path_full = path + case + '/ice/proc/tseries/day_1/'

    files = sorted(glob(f'{path_full}/{case}.cice.h1.{varname}.????????-????????.nc'))      
    ds_tmp = xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, 
                               concat_dim="time", combine='nested', decode_times=True)

    # take an average over the time bounds to get the right time dimension
    ds_tmp["time"] = ds_tmp.time_bounds.compute().mean(dim="d2")
    
    # keep only some variables
    keep_vars=['TLAT','TLON','tarea','time'] + [varname]
    ds_tmp = ds_tmp.drop([v for v in ds_tmp.variables if v not in keep_vars])
    
    ds_hist = xr.concat([ds_hist,ds_tmp], dim='member_id')
# Out:
# loading historical data
# 001
# 002
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 003
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 004
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 005
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 006
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 007
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 008
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 009
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 010
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 011
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 012
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 013
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 014
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 015
# CPU times: user 10.6 s, sys: 2.11 s, total: 12.7 s
# Wall time: 60 s
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %% [markdown]
# ### Load future data

# %%
# %%time

print('loading future data')
ds_ssp = xr.Dataset()

for m in ens_mems:
    print(m)

    case = 'b.e21.BRCP85.f09_g17.cesm2-cmip5.' + m
    path_full = path + case + '/ice/proc/tseries/day_1/'

    files = sorted(glob(f'{path_full}/{case}.cice.h1.{varname}.????????-????????.nc'))          
    ds_tmp = xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, 
                               concat_dim="time", combine='nested', decode_times=True)

    # take an average over the time bounds to get the right time dimension
    ds_tmp["time"] = ds_tmp.time_bounds.compute().mean(dim="d2")
    
    # keep only some variables
    keep_vars=['TLAT','TLONG','tarea','time'] + [varname]
    ds_tmp = ds_tmp.drop([v for v in ds_tmp.variables if v not in keep_vars])
    
    ds_ssp = xr.concat([ds_ssp,ds_tmp], dim='member_id')
# Out:
# loading future data
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# CPU times: user 8.23 s, sys: 2.01 s, total: 10.2 s
# Wall time: 51.3 s

# %% [markdown]
# ## Concatenate historical and future datasets
# - Note that historical ends on Jan 15, 2006 and the future starts Jan 1, 2006, so need to fix this before concatenating so we don't repeat days

# %%
#ds_hist.time
#ds_ssp.time

# %%
# remove the overlap days from historical simulation
ds_hist = ds_hist.where(ds_hist.time.dt.year < 2006,drop=True)
ds_hist.time
# Out:
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# <xarray.DataArray 'time' (time: 56940)>
# array([cftime.DatetimeNoLeap(1850, 1, 1, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1850, 1, 2, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1850, 1, 3, 12, 0, 0, 0, has_year_zero=True), ...,
#        cftime.DatetimeNoLeap(2005, 12, 29, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2005, 12, 30, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2005, 12, 31, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 1850-01-01 12:00:00 ... 2005-12-31 12:00:00

# %%
ds = xr.concat((ds_hist,ds_ssp),dim='time')

# %%
# keep only the point we're interested in near village
ds_village = ds.isel(nj=slice(xloc,xloc+1),ni=slice(yloc, yloc+1))

# %%
# keep just 1920-2100 for all datasets
yy_st = 1920
yy_ed = 2100

# %%
ds_subset = ds_village.where(ds_village.time.dt.year >= yy_st, drop = True)

# %%
ds_subset
# Out:
# <xarray.Dataset>
# Dimensions:  (member_id: 15, time: 66065, nj: 1, ni: 1)
# Coordinates:
#   * time     (time) object 1920-01-01 12:00:00 ... 2100-12-31 12:00:00
#     TLAT     (nj, ni) float32 71.56
#     TLON     (nj, ni) float32 203.3
# Dimensions without coordinates: member_id, nj, ni
# Data variables:
#     hi_d     (member_id, time, nj, ni) float32 dask.array<chunksize=(1, 18250, 1, 1), meta=np.ndarray>
#     tarea    (member_id, nj, ni, time) float32 dask.array<chunksize=(1, 1, 1, 31390), meta=np.ndarray>

# %%
ds_subset = ds_subset.isel(nj=0,ni=0)

# %%
ds_subset
# Out:
# <xarray.Dataset>
# Dimensions:  (member_id: 15, time: 66065)
# Coordinates:
#   * time     (time) object 1920-01-01 12:00:00 ... 2100-12-31 12:00:00
#     TLAT     float32 71.56
#     TLON     float32 203.3
# Dimensions without coordinates: member_id
# Data variables:
#     hi_d     (member_id, time) float32 dask.array<chunksize=(1, 18250), meta=np.ndarray>
#     tarea    (member_id, time) float32 dask.array<chunksize=(1, 31390), meta=np.ndarray>

# %%
# %%time
ds_subset.load()
# Out:
# CPU times: user 19min 44s, sys: 4min 19s, total: 24min 4s
# Wall time: 31min 7s
# <xarray.Dataset>
# Dimensions:  (member_id: 15, time: 66065)
# Coordinates:
#   * time     (time) object 1920-01-01 12:00:00 ... 2100-12-31 12:00:00
#     TLAT     float32 71.56
#     TLON     float32 203.3
# Dimensions without coordinates: member_id
# Data variables:
#     hi_d     (member_id, time) float32 2.238 2.287 2.316 2.36 ... 0.0 0.0 0.0
#     tarea    (member_id, time) float32 3.054e+09 3.054e+09 ... 3.054e+09

# %% [markdown]
# ## Save the variable
# - Netcdf with variable dimension: (member_id x time)
# - One netcdf per variable

# %%
ds_out = xr.Dataset()

ds_out[varname] = ds_subset[varname]

# change the attributes
ds_out.attrs['author'] = 'Alice DuVivier'
ds_out.attrs['date_processed'] = datetime.now().strftime('%Y-%m-%d')
ds_out.attrs['contents'] = f'Daily CESM2-CMIP5 data for ocean point nearest Utqiagvik'

ds_out
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 66065, member_id: 15)
# Coordinates:
#   * time     (time) object 1920-01-01 12:00:00 ... 2100-12-31 12:00:00
#     TLAT     float32 71.56
#     TLON     float32 203.3
# Dimensions without coordinates: member_id
# Data variables:
#     hi_d     (member_id, time) float32 2.238 2.287 2.316 2.36 ... 0.0 0.0 0.0
# Attributes:
#     author:          Alice DuVivier
#     date_processed:  2025-10-03
#     contents:        Daily CESM2-CMIP5 data for ocean point nearest Utqiagvik

# %%
# Print the dimensions
print("Dimensions:")
for dim in ds_out.dims:
    print(f"\t{dim}: {ds_out[dim].values.shape}")

# Print the coordinates
print("Coordinates:")
for coord in ds_out.coords:
    print(f"\t{coord}:")
    print(f"\t\t{ds_out.coords[coord].values}")
    
# Print the attributes
print("Attributes:")
for attr in ds_out.attrs:
    print(f"\t{attr}: {ds_out.attrs[attr]}")
# Out:
# Dimensions:
# 	time: (66065,)
# 	member_id: (15,)
# Coordinates:
# 	time:
# 		[cftime.DatetimeNoLeap(1920, 1, 1, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1920, 1, 2, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1920, 1, 3, 12, 0, 0, 0, has_year_zero=True) ...
#  cftime.DatetimeNoLeap(2100, 12, 29, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 12, 30, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 12, 31, 12, 0, 0, 0, has_year_zero=True)]
# 	TLAT:
# 		71.5558090209961
# 	TLON:
# 		203.34042358398438
# Attributes:
# 	author: Alice DuVivier
# 	date_processed: 2025-10-03
# 	contents: Daily CESM2-CMIP5 data for ocean point nearest Utqiagvik

# %% [markdown]
# ## Export and Save

# %%
# calculate the size of the dataset in GB
size_gb = ds_out.nbytes / (1024**3)
print(f"The dataset is approximately {size_gb:.2f} GB.")
# Out:
# The dataset is approximately 0.00 GB.

# %%
path_out = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm2-cmip5_utqiagvik/'
file_out = name_village+'_CESM2-CMIP5_1920-2100_daily-'+varname+'.nc'
fout = path_out + file_out
print(fout)
# Out:
# /glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm2-cmip5_utqiagvik/Utqiagvik_CESM2-CMIP5_1920-2100_daily-hi_d.nc

# %%
# Export the dataset to NetCDF with all attributes and coordinates
ds_out.to_netcdf(fout)
