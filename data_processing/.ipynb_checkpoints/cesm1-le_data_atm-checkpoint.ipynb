# %% [markdown]
# # Arctic Atmosphere files
#
# * **Description**: Creates file of Utqiagvik data from CESM2-LE
# * **Input data**: CESM2-le daily timeseries data
# * **Output data**: Netcdf with data
# * **Creator**: Alice DuVivier
# * **Date**: September 2024

# %% [markdown]
# ### Import Packages

# %%
#import utils
import xarray as xr
import numpy as np
from glob import glob
import importlib
from datetime import datetime
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
import cmocean

# %% [markdown]
# ## Find point nearest Utqiagvik

# %%
# set latitude and longitude of Village (longitudes must be in 0-360)
name_village = 'Utqiagvik'
lat_village = 71.29
lon_village = 203.21
#longitue = -156.79

# %%
# set a dataset to read in to get grid information
dir_in = '/glade/u/home/duvivier/masks/'
file_in = 'b.e21.BSSP370.f09_g17.rufmod.001.cam.h0.2015-01.nc'
ds = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# grab lat and lon data
lat1d = ds.lat
lon1d = ds.lon
land = ds.LANDFRAC

# %%
# First, find the index of the grid point nearest a specific lat/lon.   
abslat = np.abs(lat1d - lat_village)
abslon = np.abs(lon1d - lon_village)

# find the smallest values
xloc = np.where(abslat == np.min(abslat))
yloc = np.where(abslon == np.min(abslon))

# print index values
print(xloc[0],yloc[0])
# Out:
# [171] [163]

# %%
# Check how close these are to the latitude and longitude of the village
print(name_village+': '+str(lat_village)+','+str(lon_village))

lat_grid = lat1d.isel(lat=xloc[0]).values
lon_grid = lon1d.isel(lon=yloc[0]).values
print('grid point: '+str(lat_grid)+','+str(lon_grid))
# Out:
# Utqiagvik: 71.29,203.21
# grid point: [71.15183246],[203.75]

# %%
#create a meshgrid (2D fields of lats and lons)
lon2d,lat2d=np.meshgrid(lon1d,lat1d)

# convert the numpy array to an xarray
lon2d = xr.DataArray(lon2d,dims=('lat','lon'))
lat2d = xr.DataArray(lat2d,dims=('lat','lon'))

# assign coordinates
lon2d['lat'] = land.lat
lon2d['lon'] = land.lon
lat2d['lat'] = land.lat
lat2d['lon'] = land.lon

# %%
# Plot the Grid points to ensure we have the closest point for plots
fig = plt.figure(figsize=(20,20))

# make plot
ax = plt.subplot(1,1,1)
ax = plt.subplot(1,1,1,projection = ccrs.NorthPolarStereo(central_longitude=180.0) )
ax.set_extent([-140, -179, 72, 69], crs=ccrs.PlateCarree())

# do a pcolormesh plot of input
cs0 = ax.pcolormesh(lon1d, lat1d,
                    land.isel(time=0),
                    cmap = cmocean.cm.thermal, vmin = 0, vmax = 1,
                    transform=ccrs.PlateCarree())

# do scatter plot of all grid values
cs1 = ax.plot(lon2d, lat2d,
                 land.isel(time=0),
                 c='white',marker='.', linestyle='none',
                 transform=ccrs.PlateCarree())

# Plot requested lat/lon point
cs2 = ax.scatter(lon_village, lat_village, marker='.',c='red', transform=ccrs.PlateCarree())
tx1 = ax.text(lon_village, lat_village, 'requested', c='red', transform=ccrs.PlateCarree())

# Plot nearest point in the array red
cs4 = plt.scatter(lon2d.isel(lat=xloc[0],lon=yloc[0]), lat2d.isel(lat=xloc[0],lon=yloc[0]), marker='x', color='orange', transform=ccrs.PlateCarree())
tx2 = plt.text(lon2d.isel(lat=xloc[0],lon=yloc[0]), lat2d.isel(lat=xloc[0],lon=yloc[0]), 'selected', c='orange', transform=ccrs.PlateCarree())

# %% [markdown]
# - This point is NOT a full ocean point, so we want to grab one latitude further north instead.

# %%
# Plot the Grid points to ensure we have the closest point for plots
fig = plt.figure(figsize=(20,20))

# make plot
ax = plt.subplot(1,1,1)
ax = plt.subplot(1,1,1,projection = ccrs.NorthPolarStereo(central_longitude=180.0) )
ax.set_extent([-140, -179, 72, 69], crs=ccrs.PlateCarree())

# do a pcolormesh plot of input
cs0 = ax.pcolormesh(lon1d, lat1d,
                    land.isel(time=0),
                    cmap = cmocean.cm.thermal, vmin = 0, vmax = 1,
                    transform=ccrs.PlateCarree())

# do scatter plot of all grid values
cs1 = ax.plot(lon2d, lat2d,
                 land.isel(time=0),
                 c='white',marker='.', linestyle='none',
                 transform=ccrs.PlateCarree())

# Plot requested lat/lon point
cs2 = ax.scatter(lon_village, lat_village, marker='.',c='red', transform=ccrs.PlateCarree())
tx1 = ax.text(lon_village, lat_village, 'requested', c='red', transform=ccrs.PlateCarree())

# Plot nearest point in the array red
cs4 = plt.scatter(lon2d.isel(lat=(xloc[0]+1),lon=yloc[0]), lat2d.isel(lat=(xloc[0]+1),lon=yloc[0]), marker='x', color='orange', transform=ccrs.PlateCarree())
tx2 = plt.text(lon2d.isel(lat=(xloc[0]+1),lon=yloc[0]), lat2d.isel(lat=(xloc[0]+1),lon=yloc[0]), 'selected', c='orange', transform=ccrs.PlateCarree())

# %% [markdown]
# - This point is an ocean point and is closest to the Utqiagvik village. Proceed!

# %%
# print original index values
print(xloc[0],yloc[0])
# Out:
# [171] [163]

# %%
# set xloc and yloc so they play nicely below
xloc = 172
yloc = 163

# %%
# Check how close these are to the latitude and longitude of the village
print(name_village+': '+str(lat_village)+','+str(lon_village))

lat_grid = lat1d.isel(lat=xloc).values
lon_grid = lon1d.isel(lon=yloc).values
print('grid point: '+str(lat_grid)+','+str(lon_grid))
# Out:
# Utqiagvik: 71.29,203.21
# grid point: 72.09424083769633,203.75

# %% [markdown]
# ## Read in 35 CESM1-LE ensemble members

# %%
# Select variable of interest and locate the files
# varname options = 'WSPDSRFAV', 'TREFHT', 'UBOT', 'VBOT'

varname = 'VBOT'
path = '/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/' + varname

# %%
# list all 40 ensemble numbers
ens_mems = ['001', '002', '003', '004', '005',
            '006', '007', '008', '009', '010',
            '011', '012', '013', '014', '015',
            '016', '017', '018', '019', '020',
            '021', '022', '023', '024', '025',
            '026', '027', '028', '029', '030',
            '031', '032', '033', '034', '035']

# %% [markdown]
# ### Load historical data

# %%
# %%time

print('loading historical data')
ds_hist = xr.Dataset()

for m in ens_mems:
    print(m)

    case = 'b.e11.B20TRC5CNBDRD.f09_g16.' + m

    files = sorted(glob(f'{path}/{case}.cam.h1.{varname}.????????-????????.nc'))       
    ds_tmp = xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, 
                               concat_dim="time", combine='nested', decode_times=True)

    # keep only the point we're interested in near village
    ds_tmp = ds_tmp.isel(lat=slice(xloc,xloc+1),lon=slice(yloc,yloc+1)).compute()

    # take an average over the time bounds to get the right time dimension
    ds_tmp["time"] = ds_tmp.time_bnds.compute().mean(dim="nbnd")

    # keep only some variables
    keep_vars=['time_bnds','lat','lon','time'] + [varname]
    ds_tmp = ds_tmp.drop([v for v in ds_tmp.variables if v not in keep_vars])
    
    ds_hist = xr.concat([ds_hist,ds_tmp], dim='member_id')
# Out:
# loading historical data
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 020
# 021
# 022
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 030
# 031
# 032
# 033
# 034
# 035
# CPU times: user 10min 48s, sys: 14min 2s, total: 24min 50s
# Wall time: 26min 18s

# %% [markdown]
# ### Load future data

# %%
# %%time

print('loading future data')
ds_ssp = xr.Dataset()

for m in ens_mems:
    print(m)

    case = 'b.e11.BRCP85C5CNBDRD.f09_g16.' + m

    files = sorted(glob(f'{path}/{case}.cam.h1.{varname}.????????-????????.nc'))       
    ds_tmp = xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, 
                               concat_dim="time", combine='nested', decode_times=True)

    # keep only the point we're interested in near village
    ds_tmp = ds_tmp.isel(lat=slice(xloc,xloc+1),lon=slice(yloc,yloc+1)).compute()

    # take an average over the time bounds to get the right time dimension
    ds_tmp["time"] = ds_tmp.time_bnds.compute().mean(dim="nbnd")

    # keep only some variables
    keep_vars=['time_bnds','lat','lon','time'] + [varname]
    ds_tmp = ds_tmp.drop([v for v in ds_tmp.variables if v not in keep_vars])
    
    ds_ssp = xr.concat([ds_ssp,ds_tmp], dim='member_id')
# Out:
# loading future data
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 020
# 021
# 022
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 030
# 031
# 032
# 033
# 034
# 035
# CPU times: user 11min 26s, sys: 3min 50s, total: 15min 16s
# Wall time: 17min 19s

# %% [markdown]
# ## Concatenate historical and future datasets

# %%
ds = xr.concat((ds_hist, ds_ssp),dim='time')

# %%
# keep just 1920-2100 for all datasets
yy_st = 1920
yy_ed = 2100

# %%
ds_subset = ds.where(ds.time.dt.year >= yy_st, drop = True)

# %%
ds_subset
# Out:
# <xarray.Dataset>
# Dimensions:    (member_id: 35, time: 66065, nbnd: 2, lat: 1, lon: 1)
# Coordinates:
#   * time       (time) object 1920-01-01 00:00:00 ... 2100-12-30 12:00:00
#   * lat        (lat) float64 72.09
#   * lon        (lon) float64 203.8
# Dimensions without coordinates: member_id, nbnd
# Data variables:
#     time_bnds  (member_id, time, nbnd) object nan nan ... 2100-12-31 00:00:00
#     VBOT       (member_id, time, lat, lon) float32 nan -3.422 ... -3.968 -5.576

# %%
ds_subset = ds_subset.isel(lat=0,lon=0)

# %%
ds_subset
# Out:
# <xarray.Dataset>
# Dimensions:    (member_id: 35, time: 66065, nbnd: 2)
# Coordinates:
#   * time       (time) object 1920-01-01 00:00:00 ... 2100-12-30 12:00:00
#     lat        float64 72.09
#     lon        float64 203.8
# Dimensions without coordinates: member_id, nbnd
# Data variables:
#     time_bnds  (member_id, time, nbnd) object nan nan ... 2100-12-31 00:00:00
#     VBOT       (member_id, time) float32 nan -3.422 3.969 ... -3.968 -5.576

# %%
# %%time
ds_subset.load()
# Out:
# CPU times: user 103 µs, sys: 80 µs, total: 183 µs
# Wall time: 185 µs
# <xarray.Dataset>
# Dimensions:    (member_id: 35, time: 66065, nbnd: 2)
# Coordinates:
#   * time       (time) object 1920-01-01 00:00:00 ... 2100-12-30 12:00:00
#     lat        float64 72.09
#     lon        float64 203.8
# Dimensions without coordinates: member_id, nbnd
# Data variables:
#     time_bnds  (member_id, time, nbnd) object nan nan ... 2100-12-31 00:00:00
#     VBOT       (member_id, time) float32 nan -3.422 3.969 ... -3.968 -5.576

# %% [markdown]
# ## Save the variable
# - Netcdf with variable dimension: (member_id x time)
# - One netcdf per variable

# %%
ds_out = xr.Dataset()

ds_out[varname] = ds_subset[varname]

# change the attributes
ds_out.attrs['author'] = 'Alice DuVivier'
ds_out.attrs['date_processed'] = datetime.now().strftime('%Y-%m-%d')
ds_out.attrs['contents'] = f'Daily CESM2-LE data for ocean point nearest Utqiagvik'

ds_out
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 66065, member_id: 35)
# Coordinates:
#   * time     (time) object 1920-01-01 00:00:00 ... 2100-12-30 12:00:00
#     lat      float64 72.09
#     lon      float64 203.8
# Dimensions without coordinates: member_id
# Data variables:
#     VBOT     (member_id, time) float32 nan -3.422 3.969 ... 2.648 -3.968 -5.576
# Attributes:
#     author:          Alice DuVivier
#     date_processed:  2025-10-08
#     contents:        Daily CESM2-LE data for ocean point nearest Utqiagvik

# %%
# Print the dimensions
print("Dimensions:")
for dim in ds_out.dims:
    print(f"\t{dim}: {ds_out[dim].values.shape}")

# Print the coordinates
print("Coordinates:")
for coord in ds_out.coords:
    print(f"\t{coord}:")
    print(f"\t\t{ds_out.coords[coord].values}")
    
# Print the attributes
print("Attributes:")
for attr in ds_out.attrs:
    print(f"\t{attr}: {ds_out.attrs[attr]}")
# Out:
# Dimensions:
# 	time: (66065,)
# 	member_id: (35,)
# Coordinates:
# 	time:
# 		[cftime.DatetimeNoLeap(1920, 1, 1, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1920, 1, 1, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1920, 1, 2, 12, 0, 0, 0, has_year_zero=True) ...
#  cftime.DatetimeNoLeap(2100, 12, 28, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 12, 29, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 12, 30, 12, 0, 0, 0, has_year_zero=True)]
# 	lat:
# 		72.09424083769633
# 	lon:
# 		203.75
# Attributes:
# 	author: Alice DuVivier
# 	date_processed: 2025-10-08
# 	contents: Daily CESM2-LE data for ocean point nearest Utqiagvik

# %% [markdown]
# ## Export and Save

# %%
# calculate the size of the dataset in GB
size_gb = ds_out.nbytes / (1024**3)
print(f"The dataset is approximately {size_gb:.2f} GB.")
# Out:
# The dataset is approximately 0.01 GB.

# %%
path_out = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/cesm1-le_utqiagvik/'
file_out = name_village+'_CESM1-LE_1920-2100_daily-'+varname+'.nc'
fout = path_out + file_out

# %%
# Export the dataset to NetCDF with all attributes and coordinates
ds_out.to_netcdf(fout)
