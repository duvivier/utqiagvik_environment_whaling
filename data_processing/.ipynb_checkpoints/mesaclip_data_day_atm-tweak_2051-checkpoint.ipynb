# %% [markdown]
# # Arctic Sea ice files
#
# * **Description**: Creates file of Utqiagvik data from MESACLIP - both nearest point and average of nearby grid points
# * **Input data**: MESACLIP daily timeseries data
# * **Output data**: Netcdf with data
# * **Creator**: Alice DuVivier
# * **Date**: December 2025

# %% [markdown]
# ### Import Packages

# %%
#import utils
import xarray as xr
import numpy as np
from glob import glob
import importlib
from datetime import datetime
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
import cmocean

import dask
from dask.distributed import Client
from dask_jobqueue import PBSCluster
from ncar_jobqueue import NCARCluster
# Out:
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %%
# Create our NCAR Cluster - which uses PBSCluster under the hood
cluster = NCARCluster(walltime='6:00:00', cores=1, processes=1, memory='8 GB',interface='ext')

# Spin up 18 workers
cluster.scale(18)

# Assign the cluster to our Client
client = Client(cluster)

# %% [raw]
# cluster = NCARCluster(
#     cores=1,
#     processes=1,
#     memory="8GB",
#     #account="P93300065",
#     queue="casper",
#     walltime="02:00:00",
# )
#
# client = Client(cluster)
# cluster.scale(18)
#
# client

# %%
client
# cluster.close()
# Out:
# <Client: 'tcp://128.117.208.174:42749' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Find point nearest Utqiagvik

# %%
# set latitude and longitude of Village (longitudes must be in 0-360)
name_village = 'Utqiagvik'
lat_village = 71.29
lon_village = 203.21
#longitue = -156.79

# %% [markdown]
# ### ATM grid file

# %%
# set a dataset to read in to get grid information
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_all_arctic/daily/UBOT/'
file_in = 'MESACLIP_HIST_002_1920_UBOT_alaska_daily.nc'
ds_grid = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# grab lat and lon data
lat1d = ds_grid.lat
lon1d = ds_grid.lon
temp = ds_grid.UBOT.isel(time=0)

# %%
temp.plot()

# %%
# First, find the index of the grid point nearest a specific lat/lon.   
abslat = np.abs(lat1d - lat_village)
abslon = np.abs(lon1d - lon_village)

# find the smallest values
xloc = np.where(abslat == np.min(abslat))
yloc = np.where(abslon == np.min(abslon))

# print index values
print(xloc[0],yloc[0])
# Out:
# [85] [132]

# %%
# Check how close these are to the latitude and longitude of the village
print(name_village+': '+str(lat_village)+','+str(lon_village))

lat_grid = lat1d.isel(lat=xloc[0]).values
lon_grid = lon1d.isel(lon=yloc[0]).values
print('grid point: '+str(lat_grid)+','+str(lon_grid))
# Out:
# Utqiagvik: 71.29,203.21
# grid point: [71.375],[203.125]

# %%
#create a meshgrid (2D fields of lats and lons)
lon2d,lat2d=np.meshgrid(lon1d,lat1d)

# convert the numpy array to an xarray
lon2d = xr.DataArray(lon2d,dims=('lat','lon'))
lat2d = xr.DataArray(lat2d,dims=('lat','lon'))

# assign coordinates
lon2d['lat'] = ds_grid.lat
lon2d['lon'] = ds_grid.lon
lat2d['lat'] = ds_grid.lat
lat2d['lon'] = ds_grid.lon

# %%
# Plot the Grid points to ensure we have the closest point for plots
fig = plt.figure(figsize=(20,20))

# make plot
ax = plt.subplot(1,1,1)
ax = plt.subplot(1,1,1,projection = ccrs.NorthPolarStereo(central_longitude=180.0) )
#ax.set_extent([-140, -179, 72, 69], crs=ccrs.PlateCarree())
ax.set_extent([-155, -159, 71.5, 71], crs=ccrs.PlateCarree())

# do a pcolormesh plot of input
cs0 = ax.pcolormesh(lon2d, lat2d, temp,
                    cmap = cmocean.cm.thermal, vmin = 0, vmax = 10,
                    transform=ccrs.PlateCarree())

# do scatter plot of all grid values
#cs1 = ax.plot(lon2d, lat2d,temp,
#              c='white',marker='.', linestyle='none',
#              transform=ccrs.PlateCarree())

# Plot requested lat/lon point
cs2 = ax.scatter(lon_village, lat_village, marker='.',c='red', transform=ccrs.PlateCarree())
tx1 = ax.text(lon_village, lat_village, 'requested', c='red', transform=ccrs.PlateCarree())

# Plot nearest point in the array red
cs4 = plt.scatter(lon2d.isel(lat=xloc[0],lon=yloc[0]), lat2d.isel(lat=xloc[0],lon=yloc[0]), marker='x', color='blue', transform=ccrs.PlateCarree())
tx2 = plt.text(lon2d.isel(lat=xloc[0],lon=yloc[0]), lat2d.isel(lat=xloc[0],lon=yloc[0]), 'selected', c='blue', transform=ccrs.PlateCarree())

# %% [markdown]
# - This point is an ocean point and nearest UTQ. Proceed!

# %%
# print original index values
print(xloc[0],yloc[0])
# Out:
# [85] [132]

# %% [markdown]
# - Also find the nearest two ocean points to UTQ that are similar in scale to CESM 1deg scale to average over

# %%
# Plot the Grid points to ensure we have the closest point for plots
fig = plt.figure(figsize=(20,20))

# make plot
ax = plt.subplot(1,1,1)
ax = plt.subplot(1,1,1,projection = ccrs.NorthPolarStereo(central_longitude=180.0) )
#ax.set_extent([-140, -179, 72, 69], crs=ccrs.PlateCarree())
ax.set_extent([-155, -159, 71.5, 71], crs=ccrs.PlateCarree())

# do a pcolormesh plot of input
cs0 = ax.pcolormesh(lon2d, lat2d, temp,
                    cmap = cmocean.cm.thermal, vmin = 0, vmax = 10,
                    transform=ccrs.PlateCarree())

# Plot requested lat/lon point
cs2 = ax.scatter(lon_village, lat_village, marker='.',c='red', transform=ccrs.PlateCarree())
tx1 = ax.text(lon_village, lat_village, 'requested', c='red', transform=ccrs.PlateCarree())

# Plot nearest point in the array red
cs4 = plt.scatter(lon2d.isel(lat=xloc[0],lon=yloc[0]), lat2d.isel(lat=xloc[0],lon=yloc[0]), marker='x', color='blue', transform=ccrs.PlateCarree())
tx2 = plt.text(lon2d.isel(lat=xloc[0],lon=yloc[0]), lat2d.isel(lat=xloc[0],lon=yloc[0]), 'selected', c='blue', transform=ccrs.PlateCarree())
cs4 = plt.scatter(lon2d.isel(lat=xloc[0],lon=yloc[0]+1), lat2d.isel(lat=xloc[0],lon=yloc[0]+1), marker='x', color='blue', transform=ccrs.PlateCarree())
cs4 = plt.scatter(lon2d.isel(lat=xloc[0],lon=yloc[0]-1), lat2d.isel(lat=xloc[0],lon=yloc[0]-1), marker='x', color='blue', transform=ccrs.PlateCarree())

# %%
# print averaging index values
print(xloc[0],xloc[0])
# print averaging index values
print(yloc[0]-1,yloc[0]+1)
# Out:
# [85] [85]
# [131] [133]

# %%
# save these values to use for index below
xloc = 85
yloc_st = 131
yloc_ed = 134

# %% [markdown]
# ## Read in MESACLIP ensemble members - Historical AND two RCP options

# %%
# Select variable of interest and locate the files
# varname options = 'UBOT', 'VBOT'

varname = 'UBOT'
path = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_all_arctic/daily/' + varname

# %%
# list ensemble names
ens_mems = ['001','002', '003', '004', '005', '006', '007', '008', '009', '010']
nens = len(ens_mems)

print(nens)
# Out:
# 10

# %%
def read_data(files, varname, chunks):
    ds = xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, 
                           concat_dim="time", combine='nested', decode_times=True, chunks=chunks)
    # keep only some variables
    keep_vars=['lat','lon','time'] + [varname]
    return ds.drop([v for v in ds.variables if v not in keep_vars])

# %% [markdown]
# ### Load historical data
# - Missing 1st ensemble member data

# %%
# %%time

print('loading historical data')
ds_hist = xr.Dataset()
native_chunks={'time': 1, 'ni': 600, 'nj': 550} # ncdump -s <file> shows "aice_d:_ChunkSizes = 1, 550, 600"
better_chunks={'time': 3650, 'ni': 100, 'nj': 110} # 150 MB chunks?

for m in ens_mems[1:10]: 
    print(m)
    case = 'MESACLIP_HIST_' + m
    files = sorted(glob(f'{path}/{case}_????_{varname}_alaska_daily.nc'))       
    ds_hist = xr.concat([ds_hist,read_data(files, varname, better_chunks)], dim='member_id')
# Out:
# loading historical data
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# CPU times: user 7.63 s, sys: 42 ms, total: 7.67 s
# Wall time: 12.1 s

# %%
# %%time
# keep only box around the point we're interested in (near village); will pull out village cell AND average over box
ds_hist_village_box = ds_hist.UBOT.isel(lat=xloc,lon=slice(yloc_st,yloc_ed))
ds_hist_village_box.compute()
ds_hist_village_box
# Out:
# CPU times: user 3.21 s, sys: 340 ms, total: 3.55 s
# Wall time: 15.8 s
# <xarray.DataArray 'UBOT' (member_id: 9, time: 31475, lon: 3)>
# dask.array<getitem, shape=(9, 31475, 3), dtype=float64, chunksize=(1, 366, 3), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
#     lat      float64 71.38
#   * lon      (lon) float64 202.9 203.1 203.4
# Dimensions without coordinates: member_id
# Attributes:
#     units:         m/s
#     long_name:     Lowest model level zonal wind
#     cell_methods:  time: mean

# %%
# get the village single point and the box average
ds_hist_village = ds_hist_village_box.isel(lon=1)
ds_hist_village_box = ds_hist_village_box.mean(dim='lon')

# %% [markdown]
# ### Load future data - RCP6.0
# - Original data was missing year 2051 for ens 007, so we've just duplicated that file and read it in twice.

# %%
# %%time

print('loading RCP6.0 data')
ds_60 = xr.Dataset()
native_chunks={'time': 1, 'ni': 600, 'nj': 550} # ncdump -s <file> shows "aice_d:_ChunkSizes = 1, 550, 600"
better_chunks={'time': 3650, 'ni': 100, 'nj': 110} # 150 MB chunks?

# data available for all members
for m in ens_mems:
    print(m)
    case = 'MESACLIP_RCP6.0_' + m
    files = sorted(glob(f'{path}/{case}_????_{varname}_alaska_daily.nc'))       
    ds_60 = xr.concat([ds_60,read_data(files, varname, better_chunks)], dim='member_id')
# Out:
# loading RCP6.0 data
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/concat.py in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     241         )
#     242     return f(
# --> 243         objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs
#     244     )
#     245
#
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/concat.py in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     440     datasets = [ds.copy() for ds in datasets]
#     441     datasets = list(
# --> 442         align(*datasets, join=join, copy=False, exclude=[dim], fill_value=fill_value)
#     443     )
#     444
#
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/alignment.py in align(join, copy, indexes, exclude, fill_value, *objects)
#     366         else:
#     367             new_obj = obj.reindex(
# --> 368                 copy=copy, fill_value=fill_value, indexers=valid_indexers
#     369             )
#     370         new_obj.encoding = obj.encoding
#
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/dataset.py in reindex(self, indexers, method, tolerance, copy, fill_value, **indexers_kwargs)
#    2948             fill_value,
#    2949             sparse=False,
# -> 2950             **indexers_kwargs,
#    2951         )
#    2952
#
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/dataset.py in _reindex(self, indexers, method, tolerance, copy, fill_value, sparse, **indexers_kwargs)
#    2979             copy=copy,
#    2980             fill_value=fill_value,
# -> 2981             sparse=sparse,
#    2982         )
#    2983         coord_names = set(self._coord_names)
#
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/alignment.py in reindex_variables(variables, sizes, indexes, indexers, method, tolerance, copy, fill_value, sparse)
#     583             if not index.is_unique:
#     584                 raise ValueError(
# --> 585                     f"cannot reindex or align along dimension {dim!r} because the "
#     586                     "index has duplicate values"
#     587                 )
#
# ValueError: cannot reindex or align along dimension 'time' because the index has duplicate values

# %%
# %%time
# keep only box around the point we're interested in (near village); will pull out village cell AND average over box
ds_60_village_box = ds_60.UBOT.isel(lat=xloc,lon=slice(yloc_st,yloc_ed))
ds_60_village_box.compute()
ds_60_village_box
# Out:
# CPU times: user 2.79 s, sys: 399 ms, total: 3.19 s
# Wall time: 9.97 s
# <xarray.DataArray 'UBOT' (member_id: 6, time: 34769, lon: 3)>
# dask.array<getitem, shape=(6, 34769, 3), dtype=float64, chunksize=(1, 366, 3), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 2006-01-01 00:00:00 ... 2100-12-31 00:00:00
#     lat      float64 71.38
#   * lon      (lon) float64 202.9 203.1 203.4
# Dimensions without coordinates: member_id
# Attributes:
#     units:         m/s
#     long_name:     Lowest model level zonal wind
#     cell_methods:  time: mean

# %%
# get the village single point and the box average
ds_60_village = ds_60_village_box.isel(lon=1)
ds_60_village_box = ds_60_village_box.mean(dim='lon')

# %% [markdown]
# ### Load future data - RCP8.5

# %%
# %%time

print('loading RCP8.5 data')
ds_85 = xr.Dataset()
native_chunks={'time': 1, 'ni': 600, 'nj': 550} # ncdump -s <file> shows "aice_d:_ChunkSizes = 1, 550, 600"
better_chunks={'time': 3650, 'ni': 100, 'nj': 110} # 150 MB chunks?

# intentionally not loading first few members - no data available
for m in ens_mems[3:10]:
    print(m)
    case = 'MESACLIP_RCP8.5_' + m
    files = sorted(glob(f'{path}/{case}_????_{varname}_alaska_daily.nc'))       
    ds_85 = xr.concat([ds_85,read_data(files, varname, better_chunks)], dim='member_id')
# Out:
# loading RCP8.5 data
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# CPU times: user 6.53 s, sys: 146 ms, total: 6.68 s
# Wall time: 10 s

# %%
# %%time
# keep only box around the point we're interested in (near village); will pull out village cell AND average over box
ds_85_village_box = ds_85.UBOT.isel(lat=xloc,lon=slice(yloc_st,yloc_ed))
ds_85_village_box.compute()
ds_85_village_box
# Out:
# CPU times: user 3.42 s, sys: 462 ms, total: 3.88 s
# Wall time: 12.5 s
# <xarray.DataArray 'UBOT' (member_id: 7, time: 34769, lon: 3)>
# dask.array<getitem, shape=(7, 34769, 3), dtype=float64, chunksize=(1, 366, 3), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 2006-01-01 00:00:00 ... 2100-12-31 00:00:00
#     lat      float64 71.38
#   * lon      (lon) float64 202.9 203.1 203.4
# Dimensions without coordinates: member_id
# Attributes:
#     units:         m/s
#     long_name:     Lowest model level zonal wind
#     cell_methods:  time: mean

# %%
# get the village single point and the box average
ds_85_village = ds_85_village_box.isel(lon=1)
ds_85_village_box = ds_85_village_box.mean(dim='lon')

# %%
print('Done loading data!')
client.shutdown()

# %% [markdown]
# ## Save the variable
# - Netcdf with variable dimension: (member_id x time)
# - One netcdf per variable

# %%
varname
# Out:
# 'UBOT'

# %%
path_out = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/'

# %% [markdown]
# ### Historical File

# %%
ds_out = xr.Dataset()

ds_out['data_point'] = ds_hist_village
ds_out['data_box'] = ds_hist_village_box

# change the attributes
ds_out.attrs['author'] = 'Alice DuVivier'
ds_out.attrs['date_processed'] = datetime.now().strftime('%Y-%m-%d')
ds_out.attrs['contents'] = f'Daily MESACLIP data for ocean point nearest Utqiagvik'

ds_out
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 31475, member_id: 9)
# Coordinates:
#   * time        (time) object 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
#     lat         float64 71.38
#     lon         float64 203.1
# Dimensions without coordinates: member_id
# Data variables:
#     data_point  (member_id, time) float64 dask.array<chunksize=(1, 365), meta=np.ndarray>
#     data_box    (member_id, time) float64 dask.array<chunksize=(1, 365), meta=np.ndarray>
# Attributes:
#     author:          Alice DuVivier
#     date_processed:  2025-12-28
#     contents:        Daily MESACLIP data for ocean point nearest Utqiagvik

# %%
# Print the dimensions
print("Dimensions:")
for dim in ds_out.dims:
    print(f"\t{dim}: {ds_out[dim].values.shape}")

# Print the coordinates
print("Coordinates:")
for coord in ds_out.coords:
    print(f"\t{coord}:")
    print(f"\t\t{ds_out.coords[coord].values}")
    
# Print the attributes
print("Attributes:")
for attr in ds_out.attrs:
    print(f"\t{attr}: {ds_out.attrs[attr]}")
# Out:
# Dimensions:
# 	time: (31475,)
# 	member_id: (9,)
# Coordinates:
# 	time:
# 		[cftime.DatetimeNoLeap(1920, 1, 1, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1920, 1, 2, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1920, 1, 3, 0, 0, 0, 0, has_year_zero=True) ...
#  cftime.DatetimeNoLeap(2005, 12, 29, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2005, 12, 30, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2005, 12, 31, 0, 0, 0, 0, has_year_zero=True)]
# 	lat:
# 		71.375
# 	lon:
# 		203.125
# Attributes:
# 	author: Alice DuVivier
# 	date_processed: 2025-12-28
# 	contents: Daily MESACLIP data for ocean point nearest Utqiagvik

# %%
# calculate the size of the dataset in GB
size_gb = ds_out.nbytes / (1024**2)
print(f"The dataset is approximately {size_gb:.2f} MB.")
# Out:
# The dataset is approximately 4.56 MB.

# %%
file_out = name_village+'_MESACLIP_HIST_monthly-'+varname+'.nc'
fout = path_out + file_out
print(fout)
# Out:
# /glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/Utqiagvik_MESACLIP_HIST_monthly-UBOT.nc

# %%
# Export the dataset to NetCDF with all attributes and coordinates
ds_out.to_netcdf(fout)

# %% [markdown]
# ### RCP6.0

# %%
ds_out = xr.Dataset()

ds_out['data_point'] = ds_60_village
ds_out['data_box'] = ds_60_village_box

# change the attributes
ds_out.attrs['author'] = 'Alice DuVivier'
ds_out.attrs['date_processed'] = datetime.now().strftime('%Y-%m-%d')
ds_out.attrs['contents'] = f'Monthly MESACLIP data for ocean point nearest Utqiagvik'

ds_out
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 34769, member_id: 6)
# Coordinates:
#   * time        (time) object 2006-01-01 00:00:00 ... 2100-12-31 00:00:00
#     lat         float64 71.38
#     lon         float64 203.1
# Dimensions without coordinates: member_id
# Data variables:
#     data_point  (member_id, time) float64 dask.array<chunksize=(1, 365), meta=np.ndarray>
#     data_box    (member_id, time) float64 dask.array<chunksize=(1, 365), meta=np.ndarray>
# Attributes:
#     author:          Alice DuVivier
#     date_processed:  2025-12-28
#     contents:        Monthly MESACLIP data for ocean point nearest Utqiagvik

# %%
# Print the dimensions
print("Dimensions:")
for dim in ds_out.dims:
    print(f"\t{dim}: {ds_out[dim].values.shape}")

# Print the coordinates
print("Coordinates:")
for coord in ds_out.coords:
    print(f"\t{coord}:")
    print(f"\t\t{ds_out.coords[coord].values}")
    
# Print the attributes
print("Attributes:")
for attr in ds_out.attrs:
    print(f"\t{attr}: {ds_out.attrs[attr]}")
# Out:
# Dimensions:
# 	time: (34769,)
# 	member_id: (6,)
# Coordinates:
# 	time:
# 		[cftime.DatetimeNoLeap(2006, 1, 1, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2006, 1, 2, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2006, 1, 3, 0, 0, 0, 0, has_year_zero=True) ...
#  cftime.DatetimeNoLeap(2100, 12, 29, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 12, 30, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 12, 31, 0, 0, 0, 0, has_year_zero=True)]
# 	lat:
# 		71.375
# 	lon:
# 		203.125
# Attributes:
# 	author: Alice DuVivier
# 	date_processed: 2025-12-28
# 	contents: Monthly MESACLIP data for ocean point nearest Utqiagvik

# %%
# calculate the size of the dataset in GB
size_gb = ds_out.nbytes / (1024**2)
print(f"The dataset is approximately {size_gb:.2f} MB.")
# Out:
# The dataset is approximately 3.45 MB.

# %%
file_out = name_village+'_MESACLIP_RCP6.0_monthly-'+varname+'.nc'
fout = path_out + file_out
print(fout)
# Out:
# /glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/Utqiagvik_MESACLIP_RCP6.0_monthly-UBOT.nc

# %%
# Export the dataset to NetCDF with all attributes and coordinates
ds_out.to_netcdf(fout)

# %% [markdown]
# ### RCP8.5

# %%
ds_out = xr.Dataset()

ds_out['data_point'] = ds_85_village
ds_out['data_box'] = ds_85_village_box

# change the attributes
ds_out.attrs['author'] = 'Alice DuVivier'
ds_out.attrs['date_processed'] = datetime.now().strftime('%Y-%m-%d')
ds_out.attrs['contents'] = f'Monthly MESACLIP data for ocean point nearest Utqiagvik'

ds_out
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 34769, member_id: 7)
# Coordinates:
#   * time        (time) object 2006-01-01 00:00:00 ... 2100-12-31 00:00:00
#     lat         float64 71.38
#     lon         float64 203.1
# Dimensions without coordinates: member_id
# Data variables:
#     data_point  (member_id, time) float64 dask.array<chunksize=(1, 365), meta=np.ndarray>
#     data_box    (member_id, time) float64 dask.array<chunksize=(1, 365), meta=np.ndarray>
# Attributes:
#     author:          Alice DuVivier
#     date_processed:  2025-12-28
#     contents:        Monthly MESACLIP data for ocean point nearest Utqiagvik

# %%
# Print the dimensions
print("Dimensions:")
for dim in ds_out.dims:
    print(f"\t{dim}: {ds_out[dim].values.shape}")

# Print the coordinates
print("Coordinates:")
for coord in ds_out.coords:
    print(f"\t{coord}:")
    print(f"\t\t{ds_out.coords[coord].values}")
    
# Print the attributes
print("Attributes:")
for attr in ds_out.attrs:
    print(f"\t{attr}: {ds_out.attrs[attr]}")
# Out:
# Dimensions:
# 	time: (34769,)
# 	member_id: (7,)
# Coordinates:
# 	time:
# 		[cftime.DatetimeNoLeap(2006, 1, 1, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2006, 1, 2, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2006, 1, 3, 0, 0, 0, 0, has_year_zero=True) ...
#  cftime.DatetimeNoLeap(2100, 12, 29, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 12, 30, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 12, 31, 0, 0, 0, 0, has_year_zero=True)]
# 	lat:
# 		71.375
# 	lon:
# 		203.125
# Attributes:
# 	author: Alice DuVivier
# 	date_processed: 2025-12-28
# 	contents: Monthly MESACLIP data for ocean point nearest Utqiagvik

# %%
# calculate the size of the dataset in GB
size_gb = ds_out.nbytes / (1024**2)
print(f"The dataset is approximately {size_gb:.2f} MB.")
# Out:
# The dataset is approximately 3.98 MB.

# %%
file_out = name_village+'_MESACLIP_RCP8.5_monthly-'+varname+'.nc'
fout = path_out + file_out
print(fout)
# Out:
# /glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/Utqiagvik_MESACLIP_RCP8.5_monthly-UBOT.nc

# %%
# Export the dataset to NetCDF with all attributes and coordinates
ds_out.to_netcdf(fout)
