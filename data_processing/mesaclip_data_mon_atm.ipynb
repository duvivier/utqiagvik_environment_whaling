# %% [markdown]
# # Arctic Sea ice files
#
# * **Description**: Creates file of Utqiagvik data from MESACLIP - both nearest point and average of nearby grid points
# * **Input data**: MESACLIP daily timeseries data
# * **Output data**: Netcdf with data
# * **Creator**: Alice DuVivier
# * **Date**: December 2025

# %% [markdown]
# ### Import Packages

# %%
#import utils
import xarray as xr
import numpy as np
from glob import glob
import importlib
from datetime import datetime
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
import cmocean

import dask
from dask.distributed import Client
from dask_jobqueue import PBSCluster
from ncar_jobqueue import NCARCluster
# Out:
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %%
# Create our NCAR Cluster - which uses PBSCluster under the hood
cluster = NCARCluster(walltime='2:00:00', cores=1, processes=1, memory='8 GB',interface='ext')

# Spin up 18 workers
cluster.scale(18)

# Assign the cluster to our Client
client = Client(cluster)

# %% [raw]
# cluster = NCARCluster(
#     cores=1,
#     processes=1,
#     memory="8GB",
#     #account="P93300065",
#     queue="casper",
#     walltime="02:00:00",
# )
#
# client = Client(cluster)
# cluster.scale(18)
#
# client

# %%
client
# cluster.close()
# Out:
# <Client: 'tcp://128.117.208.173:33895' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Find point nearest Utqiagvik

# %%
# set latitude and longitude of Village (longitudes must be in 0-360)
name_village = 'Utqiagvik'
lat_village = 71.29
lon_village = 203.21
#longitue = -156.79

# %% [markdown]
# ### ATM grid file

# %%
# set a dataset to read in to get grid information
dir_in = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_all_arctic/monthly/TREFHT/'
file_in = 'MESACLIP_HIST_001_1920-2014_TREFHT_arctic_monthly.nc'
ds_grid = xr.open_mfdataset(dir_in+file_in, decode_times=False)

# %%
# grab lat and lon data
lat1d = ds_grid.lat
lon1d = ds_grid.lon
temp = ds_grid.TREFHT.isel(time=0)

# %%
# First, find the index of the grid point nearest a specific lat/lon.   
abslat = np.abs(lat1d - lat_village)
abslon = np.abs(lon1d - lon_village)

# find the smallest values
xloc = np.where(abslat == np.min(abslat))
yloc = np.where(abslon == np.min(abslon))

# print index values
print(xloc[0],yloc[0])
# Out:
# [85] [812]

# %%
# Check how close these are to the latitude and longitude of the village
print(name_village+': '+str(lat_village)+','+str(lon_village))

lat_grid = lat1d.isel(lat=xloc[0]).values
lon_grid = lon1d.isel(lon=yloc[0]).values
print('grid point: '+str(lat_grid)+','+str(lon_grid))
# Out:
# Utqiagvik: 71.29,203.21
# grid point: [71.375],[203.125]

# %%
#create a meshgrid (2D fields of lats and lons)
lon2d,lat2d=np.meshgrid(lon1d,lat1d)

# convert the numpy array to an xarray
lon2d = xr.DataArray(lon2d,dims=('lat','lon'))
lat2d = xr.DataArray(lat2d,dims=('lat','lon'))

# assign coordinates
lon2d['lat'] = ds_grid.lat
lon2d['lon'] = ds_grid.lon
lat2d['lat'] = ds_grid.lat
lat2d['lon'] = ds_grid.lon

# %%
# Plot the Grid points to ensure we have the closest point for plots
fig = plt.figure(figsize=(20,20))

# make plot
ax = plt.subplot(1,1,1)
ax = plt.subplot(1,1,1,projection = ccrs.NorthPolarStereo(central_longitude=180.0) )
ax.set_extent([-155, -159, 72, 71], crs=ccrs.PlateCarree())

# do a pcolormesh plot of input
cs0 = ax.pcolormesh(lon2d, lat2d, temp,
                    cmap = cmocean.cm.thermal, vmin = 240, vmax = 260,
                    transform=ccrs.PlateCarree())

# do scatter plot of all grid values
cs1 = ax.plot(lon2d, lat2d,temp,
              c='white',marker='.', linestyle='none',
              transform=ccrs.PlateCarree())

# Plot requested lat/lon point
cs2 = ax.scatter(lon_village, lat_village, marker='.',c='red', transform=ccrs.PlateCarree())
tx1 = ax.text(lon_village, lat_village, 'requested', c='red', transform=ccrs.PlateCarree())

# Plot nearest point in the array red
cs4 = plt.scatter(lon2d.isel(lat=xloc[0],lon=yloc[0]), lat2d.isel(lat=xloc[0],lon=yloc[0]), marker='x', color='blue', transform=ccrs.PlateCarree())
tx2 = plt.text(lon2d.isel(lat=xloc[0],lon=yloc[0]), lat2d.isel(lat=xloc[0],lon=yloc[0]), 'selected', c='blue', transform=ccrs.PlateCarree())

# %% [markdown]
# - This point is an ocean point and nearest UTQ. Proceed!

# %%
# print original index values
#print(xloc[0],yloc[0])
xloc = int(xloc[0])
yloc = int(yloc[0])

print(xloc,yloc)
# Out:
# 85 812

# %% [markdown]
# - Also find the nearest ocean points to UTQ that are similar in scale to CESM 1deg scale to average over

# %%
# Plot the Grid points to ensure we have the closest point for plots
fig = plt.figure(figsize=(20,20))

# make plot
ax = plt.subplot(1,1,1)
ax = plt.subplot(1,1,1,projection = ccrs.NorthPolarStereo(central_longitude=180.0) )
ax.set_extent([-155, -159, 72, 71], crs=ccrs.PlateCarree())

# do a pcolormesh plot of input
cs0 = ax.pcolormesh(lon2d, lat2d, temp,
                    cmap = cmocean.cm.thermal, vmin = 240, vmax = 260,
                    transform=ccrs.PlateCarree())

# do scatter plot of all grid values
cs1 = ax.plot(lon2d, lat2d,temp,
              c='white',marker='.', linestyle='none',
              transform=ccrs.PlateCarree())

# Plot requested lat/lon point
cs2 = ax.scatter(lon_village, lat_village, marker='.',c='red', transform=ccrs.PlateCarree())
tx1 = ax.text(lon_village, lat_village, 'requested', c='red', transform=ccrs.PlateCarree())

# Plot nearest point in the array red
xind_st = xloc
xind_ed = xloc+3
yind_st = yloc-1
yind_ed = yloc+2
ax.scatter(lon2d.isel(lat=slice(xind_st,xind_ed),lon=slice(yind_st,yind_ed)), lat2d.isel(lat=slice(xind_st,xind_ed),lon=slice(yind_st,yind_ed)), marker=".", color='gold',zorder=100,transform=ccrs.PlateCarree())
yind_st = yloc-1
yind_ed = yloc+2
ax.scatter(lon2d.isel(lat=xloc,lon=slice(yind_st,yind_ed)), lat2d.isel(lat=xloc,lon=slice(yind_st,yind_ed)), marker=".", color='darkorange',zorder=100,transform=ccrs.PlateCarree())
ax.scatter(lon2d.isel(lat=xloc,lon=yloc), lat2d.isel(lat=xloc,lon=yloc), marker="o",color='firebrick',zorder=100,transform=ccrs.PlateCarree())

# %%
# print averaging index values for 3x3 box
print('Indices for 3x3 box averaging')
print(xloc,xloc+3)
print(yloc-1,yloc+2)
# Out:
# Indices for 3x3 box averaging
# 85 88
# 811 814

# %%
# print averaging index values for 3x1 box
print('Indices for 3x1 box averaging')
print(xloc)
print(yloc-1,yloc+2)
# Out:
# Indices for 3x1 box averaging
# 85
# 811 814

# %% [markdown]
# ## Read in MESACLIP ensemble members - Historical AND two RCP options

# %%
# Select variable of interest and locate the files
# varname options = 'TREFHT'

varname = 'TREFHT'
path = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_all_arctic/monthly/' + varname

# %%
# list ensemble names
ens_mems = ['001','002', '003', '004', '005', '006', '007', '008', '009', '010']
nens = len(ens_mems)

print(nens)
# Out:
# 10

# %%
def read_data(files, varname, chunks):
    ds = xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, 
                           concat_dim="time", combine='nested', decode_times=True, chunks=chunks)
    # keep only some variables
    keep_vars=['lat','lon','time'] + [varname]
    return ds.drop([v for v in ds.variables if v not in keep_vars])

# %% [markdown]
# ### Load historical data

# %%
# %%time

print('loading historical data')
ds_hist = xr.Dataset()
native_chunks={'time': 1, 'ni': 600, 'nj': 550} # ncdump -s <file> shows "aice_d:_ChunkSizes = 1, 550, 600"
better_chunks={'time': 3650, 'ni': 100, 'nj': 110} # 150 MB chunks?

for m in ens_mems: 
    print(m)
    case = 'MESACLIP_HIST_' + m
    files = sorted(glob(f'{path}/{case}_1920-2014_{varname}_arctic_monthly.nc'))       
    ds_hist = xr.concat([ds_hist,read_data(files, varname, better_chunks)], dim='member_id')
# Out:
# loading historical data
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# CPU times: user 543 ms, sys: 129 ms, total: 671 ms
# Wall time: 17.3 s

# %%
#ds_hist['TREFHT'].isel(time=0,member_id=0).plot()

# %%
# keep only box around the point we're interested in (near village); will pull out village cell AND average over box
ds_hist_village_box = ds_hist[varname].isel(lat=slice(xloc,xloc+3),lon=slice(yloc-1,yloc+2))
ds_hist_village_box
# Out:
# <xarray.DataArray 'TREFHT' (member_id: 10, time: 1032, lat: 3, lon: 3)>
# dask.array<getitem, shape=(10, 1032, 3, 3), dtype=float64, chunksize=(1, 1032, 3, 3), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 1920-01-16 12:00:00 ... 2005-12-16 12:00:00
#   * lat      (lat) float64 71.38 71.62 71.88
#   * lon      (lon) float64 202.9 203.1 203.4
# Dimensions without coordinates: member_id
# Attributes:
#     units:         K
#     long_name:     Reference height temperature
#     cell_methods:  time: mean

# %% [markdown]
# ### Load future data - RCP6.0

# %%
# %%time

print('loading RCP6.0 data')
ds_60 = xr.Dataset()
native_chunks={'time': 1, 'ni': 600, 'nj': 550} # ncdump -s <file> shows "aice_d:_ChunkSizes = 1, 550, 600"
better_chunks={'time': 3650, 'ni': 100, 'nj': 110} # 150 MB chunks?

# data available for all members
for m in ens_mems:
    print(m)
    case = 'MESACLIP_RCP6.0_' + m
    files = sorted(glob(f'{path}/{case}_2015-2099_{varname}_arctic_monthly.nc'))       
    ds_60 = xr.concat([ds_60,read_data(files, varname, better_chunks)], dim='member_id')
# Out:
# loading RCP6.0 data
# 001
# 002
# 003
# 004
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 005
# 006
# 007
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# 008
# 009
# 010
# CPU times: user 243 ms, sys: 15.9 ms, total: 259 ms
# Wall time: 1.01 s
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %%
# keep only box around the point we're interested in (near village); will pull out village cell AND average over box
ds_60_village_box = ds_60[varname].isel(lat=slice(xloc,xloc+3),lon=slice(yloc-1,yloc+2))
ds_60_village_box
# Out:
# <xarray.DataArray 'TREFHT' (member_id: 10, time: 1188, lat: 3, lon: 3)>
# dask.array<getitem, shape=(10, 1188, 3, 3), dtype=float64, chunksize=(1, 1188, 3, 3), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 2006-01-16 12:00:00 ... 2104-12-16 12:00:00
#   * lat      (lat) float64 71.38 71.62 71.88
#   * lon      (lon) float64 202.9 203.1 203.4
# Dimensions without coordinates: member_id
# Attributes:
#     units:         K
#     long_name:     Reference height temperature
#     cell_methods:  time: mean

# %% [markdown]
# ### Load future data - RCP8.5

# %%
# %%time

print('loading RCP8.5 data')
ds_85 = xr.Dataset()
native_chunks={'time': 1, 'ni': 600, 'nj': 550} # ncdump -s <file> shows "aice_d:_ChunkSizes = 1, 550, 600"
better_chunks={'time': 3650, 'ni': 100, 'nj': 110} # 150 MB chunks?

# intentionally not loading first few members - no data available
for m in ens_mems[3:10]:
    print(m)
    case = 'MESACLIP_RCP8.5_' + m
    files = sorted(glob(f'{path}/{case}_2015-2099_{varname}_arctic_monthly.nc'))       
    ds_85 = xr.concat([ds_85,read_data(files, varname, better_chunks)], dim='member_id')
# Out:
# loading RCP8.5 data
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# CPU times: user 133 ms, sys: 8.4 ms, total: 142 ms
# Wall time: 750 ms

# %%
# keep only box around the point we're interested in (near village); will pull out village cell AND average over box
ds_85_village_box = ds_85[varname].isel(lat=slice(xloc,xloc+3),lon=slice(yloc-1,yloc+2))
ds_85_village_box
# Out:
# <xarray.DataArray 'TREFHT' (member_id: 7, time: 1140, lat: 3, lon: 3)>
# dask.array<getitem, shape=(7, 1140, 3, 3), dtype=float64, chunksize=(1, 1140, 3, 3), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 2006-01-16 12:00:00 ... 2100-12-16 12:00:00
#   * lat      (lat) float64 71.38 71.62 71.88
#   * lon      (lon) float64 202.9 203.1 203.4
# Dimensions without coordinates: member_id
# Attributes:
#     units:         K
#     long_name:     Reference height temperature
#     cell_methods:  time: mean

# %% [markdown]
# ## Actually load data

# %%
def compute_box_average_and_village_value(ds):
    print(f"Village is at {ds.isel(member_id=0,lat=0,lon=1)['lon'].values:.2f} E, {ds.isel(member_id=0,lat=0,lon=1)['lat'].values:.2f} N")
    ds_compute = ds.compute()
    one_pt = ds_compute.isel(lat=0,lon=1)
    small_box = ds_compute.isel(lat=0).mean(dim=["lon"])
    big_box = ds_compute.mean(dim=["lat", "lon"])
    return one_pt, small_box, big_box

# %%
# %%time
ds_hist_pt, ds_hist_small_box,ds_hist_big_box = compute_box_average_and_village_value(ds_hist_village_box)
ds_hist_village_box
# Out:
# Village is at 203.12 E, 71.38 N
# CPU times: user 210 ms, sys: 31.9 ms, total: 242 ms
# Wall time: 6.65 s
# <xarray.DataArray 'TREFHT' (member_id: 10, time: 1032, lat: 3, lon: 3)>
# dask.array<getitem, shape=(10, 1032, 3, 3), dtype=float64, chunksize=(1, 1032, 3, 3), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 1920-01-16 12:00:00 ... 2005-12-16 12:00:00
#   * lat      (lat) float64 71.38 71.62 71.88
#   * lon      (lon) float64 202.9 203.1 203.4
# Dimensions without coordinates: member_id
# Attributes:
#     units:         K
#     long_name:     Reference height temperature
#     cell_methods:  time: mean

# %%
# %%time
ds_60_pt, ds_60_small_box,ds_60_big_box = compute_box_average_and_village_value(ds_60_village_box)
ds_60_village_box
# Out:
# Village is at 203.12 E, 71.38 N
# CPU times: user 292 ms, sys: 53.6 ms, total: 346 ms
# Wall time: 7.29 s
# <xarray.DataArray 'TREFHT' (member_id: 10, time: 1188, lat: 3, lon: 3)>
# dask.array<getitem, shape=(10, 1188, 3, 3), dtype=float64, chunksize=(1, 1188, 3, 3), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 2006-01-16 12:00:00 ... 2104-12-16 12:00:00
#   * lat      (lat) float64 71.38 71.62 71.88
#   * lon      (lon) float64 202.9 203.1 203.4
# Dimensions without coordinates: member_id
# Attributes:
#     units:         K
#     long_name:     Reference height temperature
#     cell_methods:  time: mean

# %%
# %%time
ds_85_pt, ds_85_small_box,ds_85_big_box = compute_box_average_and_village_value(ds_85_village_box)
ds_85_village_box
# Out:
# Village is at 203.12 E, 71.38 N
# CPU times: user 59.8 ms, sys: 5.1 ms, total: 64.9 ms
# Wall time: 948 ms
# <xarray.DataArray 'TREFHT' (member_id: 7, time: 1140, lat: 3, lon: 3)>
# dask.array<getitem, shape=(7, 1140, 3, 3), dtype=float64, chunksize=(1, 1140, 3, 3), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 2006-01-16 12:00:00 ... 2100-12-16 12:00:00
#   * lat      (lat) float64 71.38 71.62 71.88
#   * lon      (lon) float64 202.9 203.1 203.4
# Dimensions without coordinates: member_id
# Attributes:
#     units:         K
#     long_name:     Reference height temperature
#     cell_methods:  time: mean

# %%
print('Done loading data!')
# Out:
# Done loading data!

# %% [markdown]
# ## Save the variable
# - Netcdf with variable dimension: (member_id x time)
# - One netcdf per variable

# %%
varname
# Out:
# 'TREFHT'

# %%
path_out = '/glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/'

# %% [markdown]
# ### Historical File

# %%
ds_out = xr.Dataset()

ds_out['data_pt'] = ds_hist_pt
ds_out['data_small_box'] = ds_hist_small_box
ds_out['data_big_box'] = ds_hist_big_box

# change the attributes
ds_out.attrs['author'] = 'Alice DuVivier'
ds_out.attrs['date_processed'] = datetime.now().strftime('%Y-%m-%d')
ds_out.attrs['contents'] = f'Monthly MESACLIP data for ocean point nearest Utqiagvik'

ds_out
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 1032, member_id: 10)
# Coordinates:
#   * time            (time) object 1920-01-16 12:00:00 ... 2005-12-16 12:00:00
#     lat             float64 71.38
#     lon             float64 203.1
# Dimensions without coordinates: member_id
# Data variables:
#     data_pt         (member_id, time) float64 250.0 242.2 250.5 ... 264.9 262.3
#     data_small_box  (member_id, time) float64 250.0 242.3 250.5 ... 265.1 262.5
#     data_big_box    (member_id, time) float64 250.2 242.4 250.5 ... 265.6 262.4
# Attributes:
#     author:          Alice DuVivier
#     date_processed:  2026-01-15
#     contents:        Monthly MESACLIP data for ocean point nearest Utqiagvik

# %%
# Print the dimensions
print("Dimensions:")
for dim in ds_out.dims:
    print(f"\t{dim}: {ds_out[dim].values.shape}")

# Print the coordinates
print("Coordinates:")
for coord in ds_out.coords:
    print(f"\t{coord}:")
    print(f"\t\t{ds_out.coords[coord].values}")
    
# Print the attributes
print("Attributes:")
for attr in ds_out.attrs:
    print(f"\t{attr}: {ds_out.attrs[attr]}")
# Out:
# Dimensions:
# 	time: (1032,)
# 	member_id: (10,)
# Coordinates:
# 	time:
# 		[cftime.DatetimeNoLeap(1920, 1, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1920, 2, 15, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1920, 3, 16, 12, 0, 0, 0, has_year_zero=True) ...
#  cftime.DatetimeNoLeap(2005, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2005, 11, 16, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2005, 12, 16, 12, 0, 0, 0, has_year_zero=True)]
# 	lat:
# 		71.375
# 	lon:
# 		203.125
# Attributes:
# 	author: Alice DuVivier
# 	date_processed: 2026-01-15
# 	contents: Monthly MESACLIP data for ocean point nearest Utqiagvik

# %%
# calculate the size of the dataset in GB
size_gb = ds_out.nbytes / (1024**2)
print(f"The dataset is approximately {size_gb:.2f} MB.")
# Out:
# The dataset is approximately 0.24 MB.

# %%
file_out = name_village+'_MESACLIP_HIST_monthly-'+varname+'.nc'
fout = path_out + file_out
print(fout)
# Out:
# /glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/Utqiagvik_MESACLIP_HIST_monthly-TREFHT.nc

# %%
# Export the dataset to NetCDF with all attributes and coordinates
ds_out.to_netcdf(fout)

# %% [markdown]
# ### RCP6.0

# %%
ds_out = xr.Dataset()

ds_out['data_pt'] = ds_60_pt
ds_out['data_small_box'] = ds_60_small_box
ds_out['data_big_box'] = ds_60_big_box

# change the attributes
ds_out.attrs['author'] = 'Alice DuVivier'
ds_out.attrs['date_processed'] = datetime.now().strftime('%Y-%m-%d')
ds_out.attrs['contents'] = f'Monthly MESACLIP data for ocean point nearest Utqiagvik'

ds_out
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 1188, member_id: 10)
# Coordinates:
#   * time            (time) object 2006-01-16 12:00:00 ... 2104-12-16 12:00:00
#     lat             float64 71.38
#     lon             float64 203.1
# Dimensions without coordinates: member_id
# Data variables:
#     data_pt         (member_id, time) float64 246.6 245.3 244.4 ... 272.3 271.0
#     data_small_box  (member_id, time) float64 246.7 245.3 244.4 ... 272.4 271.1
#     data_big_box    (member_id, time) float64 246.7 245.6 244.6 ... 273.3 271.8
# Attributes:
#     author:          Alice DuVivier
#     date_processed:  2026-01-15
#     contents:        Monthly MESACLIP data for ocean point nearest Utqiagvik

# %%
# Print the dimensions
print("Dimensions:")
for dim in ds_out.dims:
    print(f"\t{dim}: {ds_out[dim].values.shape}")

# Print the coordinates
print("Coordinates:")
for coord in ds_out.coords:
    print(f"\t{coord}:")
    print(f"\t\t{ds_out.coords[coord].values}")
    
# Print the attributes
print("Attributes:")
for attr in ds_out.attrs:
    print(f"\t{attr}: {ds_out.attrs[attr]}")
# Out:
# Dimensions:
# 	time: (1188,)
# 	member_id: (10,)
# Coordinates:
# 	time:
# 		[cftime.DatetimeNoLeap(2006, 1, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2006, 2, 15, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2006, 3, 16, 12, 0, 0, 0, has_year_zero=True) ...
#  cftime.DatetimeNoLeap(2104, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2104, 11, 16, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2104, 12, 16, 12, 0, 0, 0, has_year_zero=True)]
# 	lat:
# 		71.375
# 	lon:
# 		203.125
# Attributes:
# 	author: Alice DuVivier
# 	date_processed: 2026-01-15
# 	contents: Monthly MESACLIP data for ocean point nearest Utqiagvik

# %%
# calculate the size of the dataset in GB
size_gb = ds_out.nbytes / (1024**2)
print(f"The dataset is approximately {size_gb:.2f} MB.")
# Out:
# The dataset is approximately 0.28 MB.

# %%
file_out = name_village+'_MESACLIP_RCP6.0_monthly-'+varname+'.nc'
fout = path_out + file_out
print(fout)
# Out:
# /glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/Utqiagvik_MESACLIP_RCP6.0_monthly-TREFHT.nc

# %%
# Export the dataset to NetCDF with all attributes and coordinates
ds_out.to_netcdf(fout)

# %% [markdown]
# ### RCP8.5

# %%
ds_out = xr.Dataset()

ds_out['data_pt'] = ds_85_pt
ds_out['data_small_box'] = ds_85_small_box
ds_out['data_big_box'] = ds_85_big_box

# change the attributes
ds_out.attrs['author'] = 'Alice DuVivier'
ds_out.attrs['date_processed'] = datetime.now().strftime('%Y-%m-%d')
ds_out.attrs['contents'] = f'Monthly MESACLIP data for ocean point nearest Utqiagvik'

ds_out
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 1140, member_id: 7)
# Coordinates:
#   * time            (time) object 2006-01-16 12:00:00 ... 2100-12-16 12:00:00
#     lat             float64 71.38
#     lon             float64 203.1
# Dimensions without coordinates: member_id
# Data variables:
#     data_pt         (member_id, time) float64 246.5 249.0 246.3 ... 274.9 272.3
#     data_small_box  (member_id, time) float64 246.6 249.1 246.4 ... 275.0 272.4
#     data_big_box    (member_id, time) float64 245.9 248.7 246.4 ... 275.9 273.7
# Attributes:
#     author:          Alice DuVivier
#     date_processed:  2026-01-15
#     contents:        Monthly MESACLIP data for ocean point nearest Utqiagvik

# %%
# Print the dimensions
print("Dimensions:")
for dim in ds_out.dims:
    print(f"\t{dim}: {ds_out[dim].values.shape}")

# Print the coordinates
print("Coordinates:")
for coord in ds_out.coords:
    print(f"\t{coord}:")
    print(f"\t\t{ds_out.coords[coord].values}")
    
# Print the attributes
print("Attributes:")
for attr in ds_out.attrs:
    print(f"\t{attr}: {ds_out.attrs[attr]}")
# Out:
# Dimensions:
# 	time: (1140,)
# 	member_id: (7,)
# Coordinates:
# 	time:
# 		[cftime.DatetimeNoLeap(2006, 1, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2006, 2, 15, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2006, 3, 16, 12, 0, 0, 0, has_year_zero=True) ...
#  cftime.DatetimeNoLeap(2100, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 11, 16, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 12, 16, 12, 0, 0, 0, has_year_zero=True)]
# 	lat:
# 		71.375
# 	lon:
# 		203.125
# Attributes:
# 	author: Alice DuVivier
# 	date_processed: 2026-01-15
# 	contents: Monthly MESACLIP data for ocean point nearest Utqiagvik

# %%
# calculate the size of the dataset in GB
size_gb = ds_out.nbytes / (1024**2)
print(f"The dataset is approximately {size_gb:.2f} MB.")
# Out:
# The dataset is approximately 0.19 MB.

# %%
file_out = name_village+'_MESACLIP_RCP8.5_monthly-'+varname+'.nc'
fout = path_out + file_out
print(fout)
# Out:
# /glade/campaign/cgd/ppc/duvivier/arctic_actionable/DATA/mesaclip_utqiagvik/Utqiagvik_MESACLIP_RCP8.5_monthly-TREFHT.nc

# %%
# Export the dataset to NetCDF with all attributes and coordinates
ds_out.to_netcdf(fout)

# %%
print('Done loading data!')
client.shutdown()
# Out:
# Done loading data!
# tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x14bd1ece3830>, <Task finished coro=<BaseTCPListener._handle_stream() done, defined at /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/distributed/comm/tcp.py:502> exception=ValueError('invalid operation on non-started TCPListener')>)
# Traceback (most recent call last):
#   File "/glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/tornado/tcpserver.py", line 331, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#   File "/glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/distributed/comm/tcp.py", line 508, in _handle_stream
#     logger.debug("Incoming connection from %r to %r", address, self.contact_address)
#   File "/glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/distributed/comm/tcp.py", line 544, in contact_address
#     host, port = self.get_host_port()
#   File "/glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/distributed/comm/tcp.py", line 525, in get_host_port
#     self._check_started()
#   File "/glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/distributed/comm/tcp.py", line 500, in _check_started
#     raise ValueError("invalid operation on non-started TCPListener")
# ValueError: invalid operation on non-started TCPListener
# distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# _GatheringFuture exception was never retrieved
# future: <_GatheringFuture finished exception=CancelledError()>
# concurrent.futures._base.CancelledError
